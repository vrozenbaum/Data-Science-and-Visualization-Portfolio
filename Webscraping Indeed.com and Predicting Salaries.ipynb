# %% [markdown]
# # Web Scraping Indeed.com for Data Science Job Listings & Predicting Salaries

# %% [markdown]
# This project entailed using a web scraper to collect data on job postings for data scientist positions and building a binary classifier to determine whether a given job listing will be above or below the median salary.
#
# Information scraped from the webpage that was used for prediction includes: job location and job title.
# While only a small subset of the job listings included salary data, the information gained from them was used to approximate the median salary for the data science job market.
#
# Over 10,500 data science job listings were scraped over the period of three days. Out of the 10,500, only 493 listings provided annual salary information. Using the location and job title, I built several models to predict whether the salary of a given position would fall below or above the median.

# %% [markdown]
# ### Scraping job listings from Indeed.com using BeautifulSoup

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import urllib 
from urllib2 import urlopen
from itertools import compress
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.cross_validation import cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.cross_validation import train_test_split
import statsmodels.api as sm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics


# %matplotlib inline

URL = 'http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10'
html = urllib.urlopen(URL).read()
soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")
# Out:
# /Users/valeriarozenbaum/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Writing 4 functions to extract each item: location, company, job, and salary.

# %%
def extract_location(result):
    location= []
    for i in result.find_all(name = 'span', attrs={'class': 'location'}):        
        location.append(i.text)
    non_sponsored_links = []
    for i in result.find_all('td',{'class':'snip'}):
        try:
            if i.find('div',{'class':'result-link-bar-container'}).renderContents:
                non_sponsored_links.append(True) 
        except:
            non_sponsored_links.append(False)
    location = list(compress(location, non_sponsored_links))
    location = [item.encode('UTF8') for item in location]
    return location

# %%
extract_location(soup)
# Out:
# ['New York, NY',
#  'New York, NY',
#  'New York, NY',
#  'New York, NY',
#  'New Hyde Park, NY 11040',
#  'New York, NY',
#  'New York, NY',
#  'New York, NY',
#  'New York, NY',
#  'New York, NY']

# %%
#The company is set in a span with class='company'.
def extract_company(result):
    company= []
    for i in result.find_all(name = 'span', attrs={'class': 'company'}):
        try: 
            company.append(result.find_all(name = 'span', attrs = {'a data-tn-elemen': 'companyName'}).text)
        except:
            company.append(i.text)
    non_sponsored_links = []
    for i in result.find_all('td',{'class':'snip'}):
        try:
            if i.find('div',{'class':'result-link-bar-container'}).renderContents:
                non_sponsored_links.append(True) 
        except:
            non_sponsored_links.append(False)
    company = list(compress(company, non_sponsored_links))
    company = [item.encode('UTF8') for item in company]
    company = [item.replace("\n","") for item in company]
    company = [item.replace(" ","") for item in company]
    return company

extract_company(soup)
# Out:
# ['HarperCollinsPublishersInc.',
#  'Dailymotion',
#  'AdTheorent',
#  'FlatironHealth',
#  'NorthwellHealth',
#  'AdTheorent',
#  'ResearchFoundationofTheCityUniversityofNew...',
#  'HudsonData',
#  'AIG',
#  'AdTheorent']

# %%
#The title of a job is in a link with class set to jobtitle and a data-tn-element="jobTitle.
def extract_title(result):
    titles = []
    for i in result.find_all('h2',{"class":"jobtitle"}): 
        try:
            titles.append(i.find('a',{"class":"turnstileLink"})['title']) #sponsored
        except:
            titles.append("Empty")
    non_sponsored_links = []
    for i in result.find_all('td',{'class':'snip'}):
        try:
            if i.find('div',{'class':'result-link-bar-container'}).renderContents:
                non_sponsored_links.append(True) 
        except:
            non_sponsored_links.append(False)
    titles = list(compress(titles, non_sponsored_links))
    titles = [item.encode('UTF8') for item in titles]
    return titles
    
extract_title(soup)
# Out:
# ['Quantitative Scientist',
#  'Data Research Analyst - Office of Chief Nurse Executive',
#  'Director Data Science',
#  'Research Project Coordinator',
#  'Sr. Data Scientist',
#  'Scientist - Business Process Modeling and Simulation',
#  'Senior Data Scientist']

# %%
def extract_salary(result):
    salary = []
    for i in result.find_all('td',{'class':'snip'}):
        try: 
            raw_salary = i.find('nobr').text
            salary.append(raw_salary)
        except:
            salary.append('EMPTY')
    non_sponsored_links = []
    for i in result.find_all('td',{'class':'snip'}):
        try:
            if i.find('div',{'class':'result-link-bar-container'}).renderContents:
                non_sponsored_links.append(True) 
        except:
            non_sponsored_links.append(False)
    salary = list(compress(salary, non_sponsored_links))
    salary = [item.encode('UTF8') for item in salary]
    return salary

extract_salary(soup)
# Out:
# ['EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY',
#  'EMPTY']

# %% [markdown]
# ### Scaling up the  scraping

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"

max_results_per_city = 500 #This will return 500 results for each city

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Seattle', 
    'Los+Angeles', 'Philadelphia', 'Atlanta', 'Dallas', 'Houston', 'Pittsburgh', 
    'Portland', 'Phoenix', 'Denver', 'Miami', 'Ann+Arbor', 'Washington+DC']):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results     
        url = url_template.format(city, start)
        html = urllib.urlopen(url).read()
        soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")
        location = extract_location(soup)
        company = extract_company(soup)
        title = extract_title(soup)
        salary = extract_salary(soup)
        for k in range(10):
            result = []
            if k < len(location):
                result.append(location[k])
            if k < len(company):
                result.append(company[k])
            if k < len(title):
                result.append(title[k])
            if k < len(salary):
                result.append(salary[k])
            if result:
                results.append(result)

results
# Out:
# [['Houston, TX',
#   'PlatinumSolutions',
#   'Senior Data Scientist',
#   '$80,000 - $120,000 a year'],
#  ['Houston, TX', 'HP', 'Ultimate Hoops Statistician', 'EMPTY'],
#  ['Houston, TX',
#   'DavidWeekleyHomes',
#   'Associate Statistical Analyst, HSR',
#   'EMPTY'],
#  ['Houston, TX', 'Honeywell', 'Market Research Analyst', 'EMPTY'],
#  ['Sugar Land, TX 77478', 'LifeTimeFitness', 'Research Scientist', 'EMPTY'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Research Scientist - Cardiology Research',
#   'EMPTY'],
#  ['Houston, TX 77056 (Galleria-Uptown area)',
#   'Weatherford',
#   'Structuring Quantitative Analyst',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)', 'HoustonMethodist', 'EMPTY'],
#  ['Houston, TX', 'MDAndersonCancerCenter', 'EMPTY'],
#  ['Houston, TX 77056 (Galleria-Uptown area)', 'JustEnergy', 'EMPTY'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Lead Retail Pricing Scientist',
#   'EMPTY'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Research Scientist - LCMS',
#   'EMPTY'],
#  ['Houston, TX',
#   'DirectEnergy',
#   'Dealership Optimization Consultant',
#   'EMPTY'],
#  ['Houston, TX', 'GrocersSupply', 'Data Analysis Supervisor', 'EMPTY'],
#  ['Houston, TX', 'MDAndersonCancerCenter', 'Research Scientist', 'EMPTY'],
#  ['Houston, TX', 'CDKGlobal', 'Senior Scientist (Houston, TX)', 'EMPTY'],
#  ['Houston, TX', 'NCIInformationSystems,Inc.', 'Sr. Data Scientist', 'EMPTY'],
#  ['Houston, TX', 'PreferredSands', 'EMPTY'],
#  ['Houston, TX', 'KBRWyle', 'EMPTY'],
#  ['Houston, TX', 'Invesco', 'EMPTY'],
#  ['Houston, TX', 'EngagePartners', 'Data Scientist', '$120 an hour'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Sr Research Assistant - Cardiology Research',
#   'EMPTY'],
#  ['Houston, TX', 'Invesco', 'Sr. Data Scientist', 'EMPTY'],
#  ['Houston, TX',
#   'UTHealthScienceCenteratHouston',
#   'Staff Scientist - Pediatrics, Neurology',
#   'EMPTY'],
#  ['Houston, TX',
#   'BaylorCollegeofMedicine',
#   'Quality Assurance Analyst (Research)',
#   '$43,794 a year'],
#  ['Houston, TX', 'RiceUniversity', 'Development Research Analyst', 'EMPTY'],
#  ['Houston, TX',
#   'Halliburton',
#   'United States Houston:Supply Chain Statistician',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'HoustonMethodist',
#   'Research Associate II',
#   'EMPTY'],
#  ['Houston, TX',
#   'HornSolutions,Inc.',
#   'Sr Data Scientist (Hadoop) - Duluth, Georgia',
#   '$105,000 a year'],
#  ['Houston, TX 77032', 'Halliburton', 'Supply Chain Statistician', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Project Associate', 'EMPTY'],
#  ['Houston, TX', 'Jacobs', 'Mars Research Scientist', 'EMPTY'],
#  ['Houston, TX',
#   'Simple[A]',
#   'Engagement Manager for CMS Implementations',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'HoustonMethodist',
#   'Scientist',
#   'EMPTY'],
#  ['Houston, TX', 'Jacobs', 'Experimental Petrologist', 'EMPTY'],
#  ['Houston, TX', 'SNITechnology', 'ETL Informatica Developer', 'EMPTY'],
#  ['Houston, TX',
#   'BaylorCollegeofMedicine',
#   'Flow Cytometry Specialist I',
#   '$46,831 a year'],
#  ['Houston, TX 77002 (Downtown area)',
#   'GeneralElectric',
#   'Sr Staff Data Scientist',
#   'EMPTY'],
#  ['Houston, TX',
#   'UTHealthScienceCenteratHouston',
#   'Research Scientist',
#   'EMPTY'],
#  ['Houston, TX', 'Invesco', 'Lead Data Scientist', 'EMPTY'],
#  ['Houston, TX', 'Wittaff', 'Hadoop Developer w/Pentaho', 'EMPTY'],
#  ['Spring, TX', 'HRSUnlimited', 'UX Developer III', 'EMPTY'],
#  ['Houston, TX', 'UTHealthScienceCenteratHouston', 'Statistician', 'EMPTY'],
#  ['Houston, TX', 'BurgeonITServices', 'Data Scientist', 'EMPTY'],
#  ['Deer Park, TX', "SCHWAN'S", 'Food Scientist', 'EMPTY'],
#  ['Houston, TX', 'PennwellCorporation', 'Research Analyst', 'EMPTY'],
#  ['Houston, TX', 'HartEnergy', 'Senior Global Oil Market Analyst', 'EMPTY'],
#  ['Houston, TX 77018 (Northwest area)',
#   'Oracle',
#   'Database Administrator 4-IT',
#   'EMPTY'],
#  ['Houston, TX 77046 (Montrose area)',
#   'GlobalHealthcareAlliance',
#   'Data Scientist',
#   'EMPTY'],
#  ['Houston, TX',
#   'RiceUniversity',
#   'Research Scientist',
#   '$40,800 - $79,100 a year'],
#  ['Houston, TX 77042 (West Houston area)',
#   'Tessella',
#   'Senior Oil & Gas Analytics Consultant',
#   'EMPTY'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Research Statistical Analyst -Bioinformatics & Computational Biology',
#   '$66,400 - $99,600 a year'],
#  ['Houston, TX 77018 (Northwest area)',
#   'Oracle',
#   'Database Administrator 4-IT',
#   'EMPTY'],
#  ['Houston, TX',
#   'Frost&Sullivan',
#   'Senior Research Analyst in Houston, TX',
#   'EMPTY'],
#  ['Houston, TX',
#   'NationwideLaboratoryPartnersLLC',
#   'Toxicology Manager and Certifying Scientist',
#   'EMPTY'],
#  ['Houston, TX 77046 (Montrose area)',
#   'GlobalHealthcareAlliance',
#   'Data Scientist',
#   'EMPTY'],
#  ['Houston, TX',
#   'CheniereEnergy,Inc.',
#   'Analyst, Market Fundamentals (Research)',
#   'EMPTY'],
#  ['Houston, TX 77058 (Pasadena area)',
#   'TexasA&MUniversity',
#   'Postdoctoral Fellow Bioinformatics',
#   '$65,000 a year'],
#  ['Houston, TX 77046 (Montrose area)',
#   'SunnovaEnergyCorporation',
#   'Business Development/ Market Research Analyst',
#   'EMPTY'],
#  ['Houston, TX', 'OccidentalPetroleum', 'Statistician', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'MBA Consultant', 'EMPTY'],
#  ['Houston, TX', 'BelcanTechServices', 'Orbital Debris Scientist', 'EMPTY'],
#  ['Houston, TX 77042 (West Houston area)',
#   'PrimaryServices',
#   'Research Analyst - International Security',
#   'EMPTY'],
#  ['Houston, TX 77018 (Northwest area)',
#   'Oracle',
#   'Software Developer 4',
#   'EMPTY'],
#  ['Baytown, TX 77520',
#   'ExxonMobil',
#   'Research Technician Advanced Characterization',
#   'EMPTY'],
#  ['Houston, TX', 'ExperoInc', 'Front-End Programmer (React)', 'EMPTY'],
#  ['Houston, TX', 'Blinds.com', 'Digital Marketing Analyst', 'EMPTY'],
#  ['Houston, TX', 'Maana,Inc.', 'Data Scientist, Customer Solutions', 'EMPTY'],
#  ['Houston, TX',
#   'UniversityofHouston',
#   'Research Scientist - HPC Application Specialist',
#   'EMPTY'],
#  ['Sugar Land, TX',
#   'NALCOChampion,AnEcolabCompany',
#   'Principal Engineer I, RD&E',
#   'EMPTY'],
#  ['Houston, TX 77042 (West Houston area)',
#   'PrimaryServices',
#   'Research Analyst - International Security',
#   'EMPTY'],
#  ['Houston, TX',
#   'NovellaClinical',
#   'Feasibility Research Analyst II - Novella Clinical',
#   'EMPTY'],
#  ['Houston, TX', 'OccidentalPetroleum', 'Statistician', 'EMPTY'],
#  ['Houston, TX',
#   'NationwideLaboratoryPartnersLLC',
#   'Certifying Scientist / LC-MS Chemist',
#   'EMPTY'],
#  ['Sugar Land, TX 77478', 'AmerisourceBergen', 'EPA Scientist', 'EMPTY'],
#  ['Houston, TX', 'Tachyus', 'Product Manager', 'EMPTY'],
#  ['Houston, TX',
#   'QuantlabFinancial',
#   'Quantitative Research Scientist - Options Strategy',
#   'EMPTY'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Quality Assurance Specialist - Transfusion',
#   'EMPTY'],
#  ['Houston, TX',
#   'BrunelEnergy',
#   'Senior Software Developer / Big Data',
#   'EMPTY'],
#  ['Sugar Land, TX', 'QuVaPharmaInc', 'Senior Analytical Chemist', 'EMPTY'],
#  ['Houston, TX 77002 (Downtown area)',
#   'GeneralElectric',
#   'Sr Staff Analytics Engineer',
#   'EMPTY'],
#  ['Houston, TX 77058 (Pasadena area)',
#   'UniversitiesSpaceResearchAssociation',
#   'Postdoctoral Researcher: Mineralogy and Petrology of Planetary Materials',
#   'EMPTY'],
#  ['Houston, TX',
#   'McKinsey&Company',
#   'Specialist - Operations Performance, Energy Insights',
#   'EMPTY'],
#  ['Houston, TX',
#   'UTHealthScienceCenteratHouston',
#   'Program Manager- Research',
#   'EMPTY'],
#  ['Houston, TX',
#   'AlionScienceandTechnology',
#   'Air Monitoring Specialist -PM 2.5',
#   'EMPTY'],
#  ['Houston, TX',
#   'TargaResources',
#   'Senior Analyst, Technical Accounting and Research T7119',
#   'EMPTY'],
#  ['Houston, TX',
#   'Accenture',
#   'Accenture Insights Platform Product Manager, Southwest US Region',
#   'EMPTY'],
#  ['Houston, TX 77002 (Downtown area)',
#   'CelgeneCorporation',
#   'Medical Science Liaison (MSL), Hematology - Myeloid',
#   'EMPTY'],
#  ['Houston, TX', 'Jacobs', 'Orbital Debris Scientist', 'EMPTY'],
#  ['Houston, TX',
#   'BOEING',
#   'Property Accounting / Management Specialist',
#   'EMPTY'],
#  ['Houston, TX', 'BaylorCollegeofMedicine', 'Postdoctoral Associate', 'EMPTY'],
#  ['Houston, TX',
#   'Accenture',
#   'Accenture Insights Platform Product Manager, Southwest US Region',
#   'EMPTY'],
#  ['Houston, TX', 'Lonza', 'R&T Scientist III', 'EMPTY'],
#  ['Houston, TX',
#   'BOEING',
#   'Property Accounting / Management Specialist',
#   'EMPTY'],
#  ['Houston, TX', 'BRESA', 'UI/ UX Developer', 'EMPTY'],
#  ['Houston, TX',
#   'MDAndersonCancerCenter',
#   'Quality Assurance Specialist - Blood Bank',
#   'EMPTY'],
#  ['Houston, TX',
#   'BaylorCollegeofMedicine',
#   'Staff Scientist (Biocurator I)',
#   '$60,000 a year'],
#  ['Houston, TX',
#   'KBRWyle',
#   'Integrated Human Performance Lead (Houston, TX)',
#   'EMPTY'],
#  ['Houston, TX', 'Arcadis:US', 'Water Engineer Intern', 'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'HoustonMethodistResearchInstitute',
#   'Postdoctoral Fellow',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'HoustonMethodist',
#   'Project Specialist',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'HoustonMethodistResearchInstitute',
#   'Postdoctoral Fellow',
#   'EMPTY'],
#  ['Houston, TX',
#   'KBRWyle',
#   'Senior Human Factors Engineer (Houston, TX)',
#   'EMPTY'],
#  ['Houston, TX',
#   'Valic',
#   'Director, ETL Lead/Developer \xe2\x80\x93 Hadoop Ecosystem',
#   'EMPTY'],
#  ['Houston, TX 77041', 'Weatherford', 'Metallurgical Technician', 'EMPTY'],
#  ['Houston, TX', 'Nokia', 'Account Manager', 'EMPTY'],
#  ['Houston, TX',
#   'AIG',
#   'Director, ETL Lead/Developer \xe2\x80\x93 Hadoop Ecosystem',
#   'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Science Consultant', 'EMPTY'],
#  ['Houston, TX',
#   'UTHealthScienceCenteratHouston',
#   'Clinical Research Financial Analyst',
#   'EMPTY'],
#  ['Houston, TX',
#   'AFGlobalCorporation',
#   'R&D Scientist/ Lab Technician',
#   'EMPTY'],
#  ['Houston, TX', 'VWR', 'Procurement Specialist', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Engineering Consultant', 'EMPTY'],
#  ['Houston, TX',
#   'PryorPersonnelAgency,Inc.',
#   'P&C Predictive Modeling Actuarial Associate (PR9850)',
#   'EMPTY'],
#  ['Houston, TX',
#   "TexasChildren'sHospital",
#   'Medical Technologist - West Tower (3p - 11:30p)',
#   'EMPTY'],
#  ['Houston, TX', 'BaylorCollegeofMedicine', 'Associate Professor', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Java Programmer', 'EMPTY'],
#  ['Houston, TX 77046 (Montrose area)',
#   'ExxonMobil',
#   '2017 Computational Sciences - Data Scientist',
#   'EMPTY'],
#  ['Houston, TX',
#   'Smith&Associates',
#   'Data Scientist at PREDICTif Solutions',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'BellicumPharmaceuticals',
#   'Research Technician II \xe2\x80\x93 Immunotherapy',
#   'EMPTY'],
#  ['Houston, TX', 'HDR', 'Principal, Education | Science | Tech', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Quality Control Attorney', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Economics Consultant', 'EMPTY'],
#  ['Houston, TX',
#   'TexasHeartInstitute',
#   'Research Associate I in Molecular Cardiology',
#   'EMPTY'],
#  ['Houston, TX 77030 (Medical area)',
#   'HoustonMethodist',
#   'Chief Medical Technologist',
#   'EMPTY'],
#  ['Houston, TX 77032',
#   'Halliburton',
#   'R&D Chemist, Associate - R&D Chemist',
#   'EMPTY'],
#  ['Houston, TX 77032',
#   'Halliburton',
#   'HSE Manager (Radiation & Explosives)',
#   'EMPTY'],
#  ['Houston, TX',
#   "TexasChildren'sHospital",
#   'Medical Technologist - Generalist - West Campus (7a - 7p)',
#   'EMPTY'],
#  ['Houston, TX', 'WSP|ParsonsBrinckerhoff', 'Cost Control Engineer', 'EMPTY'],
#  ['Houston, TX',
#   'TexasHeartInstitute',
#   'Research Associate I in Cardiomyocyte Renewal Lab',
#   'EMPTY'],
#  ['Houston, TX 77007 (Rice Military area)',
#   'Stage3Separation',
#   'Solids Control Technician',
#   'EMPTY'],
#  ['Houston, TX', 'MEITechnologies', 'Senior Exercise Scientist', 'EMPTY'],
#  ['Houston, TX', 'alliantgroup', 'Legal Consultant', 'EMPTY'],
#  ['Houston, TX',
#   'McKinsey&Company',
#   'Analyst - Operations Performance, Energy Insights',
#   'EMPTY'],
#  ['Houston, TX',
#   'UTHealthScienceCenteratHouston',
#   'Assistant/Associate Professor or Professor - Neurology (Research)',
#   'EMPTY'],
#  ['Houston, TX',
#   'EDFTradingNorthAmericaLLC',
#   'Quant Analyst Intern - Power',
#   'EMPTY'],
#  ['Houston, TX', 'Schlumberger', 'Data Scientist', 'EMPTY'],
#  ['Houston, TX', 'BeazerHomes', 'Market Research Analyst', 'EMPTY'],
#  ['Houston, TX 77070', 'NobleEnergy,Inc.', 'Data Scientist', 'EMPTY'],
#  ['Houston, TX', 'LegacyMedSearch', 'Staff Scientist', 'EMPTY'],
#  ['Houston, TX',
#   "TexasChildren'sHospital",
#   'Technical Supervisor - Laboratory - West Campus (8a - 5p)',
#   'EMPTY'],
#  ['Houston, TX',
#   'Bechtel',
#   'Chief Technology Officer - Water Business Line Job',
#   'EMPTY'],
#  ['Houston, TX',
#   "TexasChildren'sHospital",
#   'Technical Supervisor - Laboratory - West Campus (8a - 5p)',
#   'EMPTY'],
#  ['Houston, TX',
#   'MacquarieGroupLimited',
#   'Data Scientist Internship, Energy Markets Division - Commodities and Global Markets',
#   'EMPTY'],
#  ['Houston, TX', 'Elsevier', 'Exam Admin', 'EMPTY'],
#  ['Houston, TX 77042 (West Houston area)',
#   'I.T.Staffing',
#   'Data Scientist \xe2\x80\x93 Machine Learning',
#   'EMPTY'],
#  ['Houston, TX 77024 (Greater Memorial area)',
#   'PREDICTifSolutions',
#   'Data Scientist',
#   'EMPTY'],
#  ['Houston, TX', 'WalkerElliott', 'Data Scientist', 'EMPTY'],
#  ['Houston, TX 77001', 'AstronInternational,Inc', 'Product Manager', 'EMPTY'],
#  ['Houston, TX 77084',
#   'AramcoServicesCompany',
#   'Lab Technician Specialist (327863)',
#   'EMPTY'],
#  ['Houston, TX',
#   'MemorialHermann',
#   'Supplemental MEG (Magnetoencepholography)/EEG (Electroencephalogram) Technologist',
#   'EMPTY'],
#  ['Houston, TX 77002 (Downtown area)',
#   'GeneralElectric',
#   'Senior Data Scientist',
#   'EMPTY'],
#  ['Houston, TX', 'Odfjell', 'Environmental Specialist', 'EMPTY'],
#  ['Houston, TX', 'WasteManagement', 'Senior Data Scientist', 'EMPTY'],
#  ['Houston, TX 77084',
#   'AramcoServicesCompany',
#   'Lab Technician Specialist (327863)',
#   'EMPTY'],
#  ['Houston, TX',
#   'MemorialHermann',
#   'Supplemental MEG (Magnetoencepholography)/EEG (Electroencephalogram) Technologist',
#   'EMPTY'],
#  ['Spring, TX 77389', 'FirstGenesis', 'Sr. UX Designer Professional', 'EMPTY'],
#  ['Houston, TX',
#   'Kinetix',
#   'Medical Technologist - Medical Center- Pavilion for Women (Multiple Shifts)',
#   'EMPTY'],
#  ['Houston, TX',
#   "TexasChildren'sHospital",
#   'Medical Technologist - Blood Bank / General Lab Asst. - West Campus (10:30p - 7a)',
#   'EMPTY'],
#  ['Washington, DC',
#   'GuntherDouglas,Inc.',
#   'Data Science Professional',
#   '$110,000 - $140,000 a year'],
#  ['Washington, DC', 'Aveshka,Inc.', 'Data Subject Matter Expert', 'EMPTY'],
#  ['Washington, DC', 'NPR', 'Data Science Evangelist', 'EMPTY'],
#  ['McLean, VA 22102', 'FreddieMac', 'Data Scientist / Analyst', 'EMPTY'],
#  ['Washington, DC', 'AxiologicSolutions', 'Junior Data Scientist', 'EMPTY'],
#  ['Washington, DC', 'DataRobot', 'Data Scientist', 'EMPTY'],
#  ['Washington, DC',
#   'BoozAllenHamilton',
#   'SAS Statistician/Research Analyst',
#   'EMPTY'],
#  ['Rosslyn, VA', 'BitVoyant', 'EMPTY'],
#  ['Washington, DC', 'CentralIntelligenceAgency', '$62,338 - $119,794 a year'],
#  ['Washington, DC 20210 (Capitol Hill area)',
#   'AssociatedVeterans,LLC',
#   'EMPTY'],
#  ['Washington, DC',
#   'GeorgeWashingtonMedicalFacultyAssociates',
#   'Cleared Jr. Data Scientist',
#   'EMPTY'],
#  ['Washington, DC', 'Plus3ITSystems', 'Data Scientist', 'EMPTY'],
#  ['Washington, DC',
#   'GeneralAssembly',
#   'Polling and Research Analyst',
#   'EMPTY'],
#  ['Silver Spring, MD 20910', 'RedJack,LLC', 'Staff Scientist', 'EMPTY'],
#  ['Washington, DC',
#   'WorkbridgeAssociates',
#   'Statistical Regression Analyst',
#   '$100,000 - $150,000 a year'],
#  ['Washington, DC 20037 (Foggy Bottom area)',
#   'AtlanticMedia',
#   'Machine Learning - R&D TS Clearance',
#   'EMPTY'],
#  ['Arlington, VA', 'BoozAllenHamilton', 'Research Analyst', 'EMPTY'],
#  ['Arlington, VA 22202 (Aurora Highlands area)',
#   'TechnologyServiceCorporation',
#   'EMPTY'],
#  ['Arlington, VA', 'BaroneConsulting', 'EMPTY'],
#  ['College Park, MD', 'UniversityofMaryland', 'EMPTY'],
#  ['Bethesda, MD 20814', 'ChildTrends', 'Senior Data Analyst', 'EMPTY'],
#  ['Rockville, MD', 'KarnaLLC', 'Statistician - FAA', 'EMPTY'],
#  ['Washington, DC 20024 (South West area)',
#   'MathematicaPolicyResearch',
#   'Research Analyst',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'BlueSkyInnovativeSolutions',
#   'Jr. Data Scientist/ Programmer',
#   'EMPTY'],
#  ['Washington, DC', 'EngilityCorporation', 'Data & Research Analyst', 'EMPTY'],
#  ['Bethesda, MD', 'Streetsense', 'Statistician/Econometrician', 'EMPTY'],
#  ['Bethesda, MD', 'Leidos', 'Statistical Analyst', 'EMPTY'],
#  ['Washington, DC', 'TheCouncil', '$80,000 - $85,000 a year'],
#  ['Washington, DC', 'AmericanInstitutesforResearch', 'EMPTY'],
#  ['Arlington, VA', 'MbSolutionsInc', '$80,000 a year'],
#  ['Silver Spring, MD 20910',
#   'TheHenryM.JacksonFoundation',
#   'Program Scientist',
#   'EMPTY'],
#  ['McLean, VA', 'MitreCorporation', 'Junior Data Scientist', 'EMPTY'],
#  ['Tysons, VA', 'ObjectVideo,Inc.', 'Research Scientist', 'EMPTY'],
#  ['Bethesda, MD',
#   'CenterforCancerResearch',
#   'Chief, Cancer Data Science Laboratory',
#   'EMPTY'],
#  ['Herndon, VA',
#   'SDLGovernment',
#   'MT / NLP / Data Analytics Technologist',
#   'EMPTY'],
#  ['McLean, VA', 'CapitalOne', 'Machine Learning Data Engineer', 'EMPTY'],
#  ['Arlington, VA', 'SalientCRGT', 'Data Governance Lead', 'EMPTY'],
#  ['Bethesda, MD 20814', 'TheHenryM.JacksonFoundation', 'Scientist', 'EMPTY'],
#  ['Washington, DC', 'CentraTechnology', 'FEMA Research Analyst', 'EMPTY'],
#  ['Washington, DC',
#   'PopulationActionInternational(PAI)',
#   'Senior Research & Policy Analyst',
#   '$65,000 - $80,000 a year'],
#  ['Arlington, VA', 'USC', 'Junior Data Scientist', 'EMPTY'],
#  ['Washington, DC',
#   'VoxMedia',
#   'Machine Learning Engineer - Data Scientist',
#   'EMPTY'],
#  ['Washington, DC',
#   'CapgeminiGovernmentSolutions',
#   'Research Analyst',
#   'EMPTY'],
#  ['McLean, VA', 'MitreCorporation', 'Data Scientist Intern', 'EMPTY'],
#  ['Fairfax, VA',
#   'GLIDER.ai',
#   'Staff Scientist-Senior Level (Security Clearance Needed)',
#   'EMPTY'],
#  ['Washington, DC',
#   'TheWorldBankGroup',
#   'Analyst - Healthcare Analytics & Delivery, McKinsey New Ventures',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'TheRockCreekGroup',
#   'Research Analyst III - Education Research Center',
#   'EMPTY'],
#  ['Arlington, VA', 'StrategicAnalysis,Inc', 'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)', 'McKinsey&Company', 'EMPTY'],
#  ['College Park, MD', 'OptimalSolutionsGroup,LLC', 'EMPTY'],
#  ['McLean, VA', 'MitreCorporation', 'Quantitative Analyst Intern', 'EMPTY'],
#  ['College Park, MD',
#   'UniversityofMaryland',
#   'Research & Assessment Analyst - Department of Resident Life',
#   'EMPTY'],
#  ['Herndon, VA',
#   'BoozAllenHamilton',
#   'Employee Payables Data Analysis Specialist',
#   'EMPTY'],
#  ['Washington, DC 20010 (Columbia Heights area)',
#   'TheHenryM.JacksonFoundation',
#   'Research Assistant',
#   'EMPTY'],
#  ['Washington, DC', 'ConceptsBeyond', 'Research Data Analyst', 'EMPTY'],
#  ['Washington, DC', 'Noblis', 'Statistician', 'EMPTY'],
#  ['Washington, DC 20037 (Foggy Bottom area)',
#   'TheUrbanInstitute',
#   'Data Visualization Specialist',
#   'EMPTY'],
#  ['College Park, MD',
#   'UniversityofMaryland',
#   'Senior Research Technology Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'BoozAllenHamilton',
#   'Data Visualization Engineer, Senior',
#   'EMPTY'],
#  ['Silver Spring, MD',
#   'ManTechInternationalCorporationReqID89729BR',
#   'Research Analyst',
#   'EMPTY'],
#  ['Arlington, VA',
#   'IntegralConsultingServices,Inc.',
#   '3032-Operations Research Analyst - Journeyman II',
#   'EMPTY'],
#  ['Annapolis Junction, MD',
#   'BoozAllenHamilton',
#   'Data Scientist / Operations Research Analyst',
#   'EMPTY'],
#  ['McLean, VA', 'CapitalOne', 'Principal Data Scientist', 'EMPTY'],
#  ['McLean, VA',
#   'BoozAllenHamilton',
#   'Analytics Data Scientist / Analyst',
#   'EMPTY'],
#  ['Herndon, VA 20171',
#   'CACI',
#   'Machine Learning Analyst / Data Scientist',
#   'EMPTY'],
#  ['McLean, VA', 'CircleBackInc.', 'Sr. Data Scientist', 'EMPTY'],
#  ['Rockville, MD',
#   'Mid-AtlanticPermanenteMedicalGroup',
#   'Research Data Analyst II (SAS Required)',
#   'EMPTY'],
#  ['Washington, DC',
#   'SAIC',
#   'NAVTAC II Operations Research Analyst (ORA-1) Job',
#   'EMPTY'],
#  ['Arlington, VA', 'ECSFederalLLC', 'Junior Scientist / Engineer', 'EMPTY'],
#  ['Reston, VA', 'MetroStarSystems', 'Data SME', 'EMPTY'],
#  ['Md City, MD',
#   'TheVeritasHealthcareSolutionsLLC.',
#   'Process/ Scientist',
#   '$40 an hour'],
#  ['Washington, DC 20037 (Foggy Bottom area)',
#   'AtlanticMedia',
#   'Research Analyst, Policy Brands Roundtable',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'AmericanSocietyforEngineeringEducation(ASEE)',
#   'Research Analyst',
#   '$50,000 a year'],
#  ['Washington, DC',
#   "Children'sNationalMedicalCenter",
#   'Bioinformatics Analyst I',
#   'EMPTY'],
#  ['Reston, VA', 'Noblis', 'Data Analytics Developer', 'EMPTY'],
#  ['Washington, DC',
#   'SouthwestResearchInstitute',
#   'RESEARCH ANALYST \xe2\x80\x93 SOFTWARE DEVELOPMENT -WASHINGTON, D.C.',
#   'EMPTY'],
#  ['Herndon, VA 20171',
#   'UrbanScience',
#   'Intern - Network Analysis Team (data analysis, SQL, advanced Excel)',
#   'EMPTY'],
#  ['Bethesda, MD 20813',
#   'Leidos',
#   'Brain Trauma Research Scientist (Neuroscientist)',
#   'EMPTY'],
#  ['Alexandria, VA 22315',
#   'StrategicManagement',
#   'Healthcare Statistical Analyst',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'Exponent',
#   'Environmental Modeler',
#   'EMPTY'],
#  ['Rockville, MD 20850', 'BLHTechnologies,Inc.', 'Statistician', 'EMPTY'],
#  ['Washington, DC',
#   'Catalist',
#   'Senior Product Manager',
#   '$70,000 - $100,000 a year'],
#  ['Silver Spring, MD',
#   'CamrisInternational',
#   'Behavioral Research Scientist',
#   'EMPTY'],
#  ['Washington, DC',
#   'BoozAllenHamilton',
#   'Operations Research Analyst, Mid',
#   'EMPTY'],
#  ['Washington, DC',
#   'HowardUniversity',
#   'Research Scientist - Center for Sickle Cell Disease',
#   'EMPTY'],
#  ['Washington, DC', 'MissingLinkSecurity', 'Jr. Management Analyst', 'EMPTY'],
#  ['Washington, DC 20037 (Foggy Bottom area)',
#   'VandaPharmaceuticalsInc.',
#   'Statistical Analyst',
#   'EMPTY'],
#  ['Arlington, VA',
#   'InternationalDevelopmentGroup',
#   'Senior Statistician',
#   'EMPTY'],
#  ['Washington, DC',
#   'TheNatureConservancy',
#   'Lead Scientist-Climate Change',
#   'EMPTY'],
#  ['Arlington, VA 22201 (Lyon Village area)',
#   'AECOM',
#   'Entry-level Technology Analyst',
#   'EMPTY'],
#  ['Springfield, VA', 'BoozAllenHamilton', 'Data Analyst', 'EMPTY'],
#  ['Reston, VA', 'FractalIndustries', 'Data Analytics Engineer', 'EMPTY'],
#  ['Arlington, VA',
#   'StrategicAnalysis,Inc',
#   'Staff Scientist-Junior Level (Security Clearance Needed)',
#   'EMPTY'],
#  ['Laurel, MD',
#   'TheJohnsHopkinsAppliedPhysicsLaboratory',
#   'Statistician',
#   'EMPTY'],
#  ['Arlington, VA 22209 (Radnor-Ft Myer Heights area)',
#   'SRIInternational',
#   'Sr. Research Analyst',
#   'EMPTY'],
#  ['Bethesda, MD', 'ACIFederal', 'Statistician', 'EMPTY'],
#  ['Washington, DC', 'MissingLinkSecurity', 'Jr. Management Analyst', 'EMPTY'],
#  ['Vienna, VA', 'BRTRC', 'Research Analyst', 'EMPTY'],
#  ['McLean, VA', 'CapitalOne', 'Data Science Manager', 'EMPTY'],
#  ['Washington, DC',
#   'SouthwestResearchInstitute',
#   'RESEARCH ANALYST \xe2\x80\x93 SOFTWARE DEVELOPMENT -WASHINGTON, D.C.',
#   'EMPTY'],
#  ['College Park, MD',
#   'I.M.SystemsGroup(IMSG)',
#   'NOA1764: Support Scientist-Model Evaluation Group',
#   'EMPTY'],
#  ['Washington, DC',
#   'TheCatholicUniversityofAmerica',
#   'Research Analyst I',
#   'EMPTY'],
#  ['Silver Spring, MD',
#   'OdysseySystemsConsultingGroup',
#   'Brain Trauma Research Scientist (Scientific Services) - (WRAIR)',
#   'EMPTY'],
#  ['Reston, VA', 'FractalIndustries', 'Data Analytics Engineer', 'EMPTY'],
#  ['Laurel, MD',
#   'TheJohnsHopkinsAppliedPhysicsLaboratory',
#   'Statistician',
#   'EMPTY'],
#  ['Washington, DC 20024 (South West area)',
#   'MitreCorporation',
#   'Lead Data Scientist',
#   'EMPTY'],
#  ['McLean, VA',
#   'BoozAllenHamilton',
#   'Busness Development Research Analyst',
#   'EMPTY'],
#  ['Washington, DC 20006 (Foggy Bottom area)',
#   'Accenture',
#   'Artificial Intelligence Manager - Southeast',
#   'EMPTY'],
#  ['Reston, VA 20191', 'Tellius', 'Solutions Enginner', 'EMPTY'],
#  ['Arlington, VA',
#   'BAESystems',
#   'Machine Learning Research Engineer',
#   'EMPTY'],
#  ['Washington, DC',
#   'UkpeagvikI\xc3\xb1upiatCorporation/BowheadFamilyofCo...',
#   'Statistician',
#   'EMPTY'],
#  ['Reston, VA',
#   'SynchronossTechnologies,Inc.',
#   'Data Scientist - Data Analyst',
#   'EMPTY'],
#  ['Reston, VA', 'Synchronoss', 'Data Scientist - Data Analyst', 'EMPTY'],
#  ['McLean, VA',
#   'VarenTechnologies',
#   'Information Technology Data Analyst, Sr.',
#   'EMPTY'],
#  ['Springfield, VA',
#   'OGSystems',
#   'Statistician/Data Scientist - Junior, Mid & Senior',
#   'EMPTY'],
#  ['Washington, DC 20005 (Logan Circle area)',
#   'iiTS',
#   'Credit Risk Transfer Research Analyst',
#   '$140,000 a year'],
#  ['Laurel, MD',
#   'TheJohnsHopkinsAppliedPhysicsLaboratory',
#   'Contamination Modeling Scientist',
#   'EMPTY'],
#  ['Reston, VA 20190',
#   'ZPGroup',
#   'Senior Data Scientist',
#   '$180,000 - $200,000 a year'],
#  ['Washington, DC',
#   'UnitedStatesPostalService',
#   'NETWORK OPERATIONS RESEARCH ANALYST EAS',
#   '$66,829 - $110,664 a year'],
#  ['Reston, VA 20191', 'Tellius', 'Solutions Enginner', 'EMPTY'],
#  ['McLean, VA',
#   'MitreCorporation',
#   'Operations Research Analyst / Statistician Intern',
#   'EMPTY'],
#  ['McLean, VA',
#   'BoozAllenHamilton',
#   'Busness Development Research Analyst',
#   'EMPTY'],
#  ['College Park, MD',
#   'I.M.SystemsGroup(IMSG)',
#   'NOA1764: Support Scientist-Model Evaluation Group',
#   'EMPTY'],
#  ['Washington, DC', 'BAESystems', 'Financial Research Analyst', 'EMPTY'],
#  ['Washington, DC', 'FP1Strategies', 'Research Analyst', 'EMPTY'],
#  ['Springfield, VA', 'Novetta', 'Data Scientist/Data Engineer', 'EMPTY'],
#  ['McLean, VA',
#   'BoozAllenHamilton',
#   'Business Development Research Analyst',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'Exponent',
#   'Epidemiologist',
#   'EMPTY'],
#  ['Arlington, VA', 'ECSFederalLLC', 'Scientist / Engineer', 'EMPTY'],
#  ['Washington, DC',
#   'LSTechnologies,LLC',
#   'Operations Research Analyst/Data Scientist - Washington, DC',
#   'EMPTY'],
#  ['Bethesda, MD',
#   'NationalOpinionResearchCenter(NORC)',
#   'Research Scientist - Health Care',
#   'EMPTY'],
#  ['Chantilly, VA', 'Vencore', 'Predictive Modeling Analyst I', 'EMPTY'],
#  ['Alexandria, VA',
#   'HumanResourcesResearchOrganization',
#   'Senior Staff Scientist - MAR16-02',
#   'EMPTY'],
#  ['Greenbelt, MD',
#   'ASRCFederal',
#   'Education and Public Outreach Specialist-summer hire',
#   'EMPTY'],
#  ['Arlington, VA 22209 (Radnor-Ft Myer Heights area)',
#   'SRIInternational',
#   'Research Analyst II - Center for Technology in Learning',
#   'EMPTY'],
#  ['Silver Spring, MD',
#   'CamrisInternational',
#   'Brain Trauma Research Scientist (Neuroscientist)',
#   'EMPTY'],
#  ['Lanham, MD', 'Noblis', 'Lead Data Analytics Developer', 'EMPTY'],
#  ['Bethesda, MD', 'Vencore', 'Scientist 2', 'EMPTY'],
#  ['Washington, DC',
#   'OakRidgeAssociatedUniversities',
#   'Drinking Water Data Analysis and Outreach',
#   'EMPTY'],
#  ['Bethesda, MD 20817',
#   'TheHenryM.JacksonFoundation',
#   'Research Data Analyst',
#   'EMPTY'],
#  ['Bowie, MD', 'Exponent', 'Managing Engineer', 'EMPTY'],
#  ['Reston, VA',
#   'SynchronossTechnologies,Inc.',
#   'Data Scientist - Data Analyst',
#   'EMPTY'],
#  ['College Park, MD',
#   'I.M.SystemsGroup(IMSG)',
#   'NOA1763-Support Scientist-Space Weather',
#   'EMPTY'],
#  ['Reston, VA', 'Synchronoss', 'Data Scientist - Data Analyst', 'EMPTY'],
#  ['Arlington, VA',
#   'FrontierTechnology,Inc.',
#   'Operations Research Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'ValiantHarborInternational,LLC',
#   'Research Analyst',
#   'EMPTY'],
#  ['Springfield, VA', 'Novetta', 'Data Scientist/Data Engineer', 'EMPTY'],
#  ['Bethesda, MD', 'Vencore', 'Scientist 2', 'EMPTY'],
#  ['Arlington, VA 22202 (Aurora Highlands area)',
#   'ConservationInternational',
#   'Post-doctoral Social Scientist, Impact Evaluation',
#   'EMPTY'],
#  ['Washington, DC', 'CEB', 'Quantitative Consultant', 'EMPTY'],
#  ['Washington, DC', 'CSRA', 'EDW Team Lead', 'EMPTY'],
#  ['Washington, DC',
#   'LSTechnologies,LLC',
#   'Operations Research Analyst/Data Scientist - Washington, DC',
#   'EMPTY'],
#  ['Washington, DC', 'CommunityScience', 'Senior Associate', 'EMPTY'],
#  ['Silver Spring, MD', 'Vencore', 'Operations Research Analyst', 'EMPTY'],
#  ['National Harbor, MD', 'Novetta', 'Computer Scientist', 'EMPTY'],
#  ['Suitland, MD', 'Vencore', 'Image Scientist', 'EMPTY'],
#  ['Arlington, VA 22209 (Radnor-Ft Myer Heights area)',
#   'SRIInternational',
#   'Research Analyst II - Center for Technology in Learning',
#   'EMPTY'],
#  ['Reston, VA 20190',
#   'ZPGroup',
#   'Senior Data Scientist',
#   '$180,000 - $200,000 a year'],
#  ['College Park, MD',
#   'EarthResourcesTechnology,Inc',
#   'Satellite Sensor Calibration Scientist',
#   'EMPTY'],
#  ['Bethesda, MD 20814', 'RosettiStarr', 'Senior Research Analyst', 'EMPTY'],
#  ['Reston, VA', 'LexisNexis', 'Court Research Analyst', 'EMPTY'],
#  ['McLean, VA',
#   'CentraTechnology',
#   'Subject Matter Expert, Operations Research Analyst',
#   'EMPTY'],
#  ['Chantilly, VA', 'Vencore', 'Predictive Modeling Analyst I', 'EMPTY'],
#  ['Rockville, MD',
#   'GlaxoSmithKline',
#   'Expert Scientist, Vaccines Preclinical Evidence Generation',
#   'EMPTY'],
#  ['Fort Meade, MD 20755',
#   'EngilityCorporation',
#   'All Source Research Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'OakRidgeAssociatedUniversities',
#   'Drinking Water Data Analysis and Outreach',
#   'EMPTY'],
#  ['Bethesda, MD 20817',
#   'TheHenryM.JacksonFoundation',
#   'Research Data Analyst',
#   'EMPTY'],
#  ['Lanham, MD', '2U', 'Market Research Analyst', 'EMPTY'],
#  ['Washington, DC', 'BDSMarketing', 'Sr. Analyst Research Services', 'EMPTY'],
#  ['Washington, DC 20002 (Capitol Hill area)',
#   'SierraClub',
#   'Electric Sector Analyst, Research and Evaluation - Beyond Coal Campaign',
#   'EMPTY'],
#  ['McLean, VA', 'Vencore', 'Data Engineer SME', 'EMPTY'],
#  ['Bethesda, MD 20814',
#   'DillonAllman&Partners',
#   'Research Associate',
#   'EMPTY'],
#  ['Greenbelt, MD',
#   'UniversitiesSpaceResearchAssociation',
#   'Research Scientist II',
#   'EMPTY'],
#  ['Arlington, VA', 'BoozAllenHamilton', 'Research Program Analyst', 'EMPTY'],
#  ['Washington, DC', 'Simple[A]', 'Engagement Manager', 'EMPTY'],
#  ['College Park, MD', 'Goldbelt,Inc.', 'Statistician', 'EMPTY'],
#  ['McLean, VA', 'Vencore', 'Data Engineer', 'EMPTY'],
#  ['Silver Spring, MD 20910',
#   'Social&ScientificSystemsInc.',
#   'Statistical Programmer',
#   'EMPTY'],
#  ['Reston, VA', 'comScore', 'Sr Statistical Analyst', 'EMPTY'],
#  ['McLean, VA 22108', 'Leidos', 'Data Engineer', 'EMPTY'],
#  ['McLean, VA', 'Neustar,Inc.', 'BI/Visualization Analyst', 'EMPTY'],
#  ['McLean, VA', 'CapitalOne', 'Senior Associate, Data Science', 'EMPTY'],
#  ['Arlington, VA 22201 (Lyon Village area)',
#   'In-Q-Tel',
#   'Geospatial Data Engineer',
#   'EMPTY'],
#  ['Alexandria, VA',
#   'HumanResourcesResearchOrganization',
#   'Research Scientist - JUL16-02',
#   'EMPTY'],
#  ['Arlington, VA',
#   'BoozAllenHamilton',
#   'Defense Research Analyst, Mid',
#   'EMPTY'],
#  ['Silver Spring, MD',
#   'FlashX',
#   'Software Engineer',
#   '$80,000 - $120,000 a year'],
#  ['Fairfax, VA',
#   'SP+',
#   'Intern \xe2\x80\x93 Field Data Analysis and Administration',
#   'EMPTY'],
#  ['Rockville, MD', 'EMD', 'Scientist', 'EMPTY'],
#  ['Washington, DC',
#   "Children'sNationalMedicalCenter",
#   'STAFF SCIENTIST I',
#   'EMPTY'],
#  ['McLean, VA', 'Vencore', 'Expert Data Engineer', 'EMPTY'],
#  ['Washington, DC', 'Cognitio', 'Washington', 'EMPTY'],
#  ['Arlington, VA', 'ECSFederalLLC', 'Senior Scientist / Engineer', 'EMPTY'],
#  ['Washington, DC 20001 (Shaw area)', 'Leidos', 'Statistician', 'EMPTY'],
#  ['Washington, DC 20009 (U Street Corridor area)',
#   'AmericanGeophysicalUnion',
#   'Data Quality Coordinator',
#   'EMPTY'],
#  ['Bethesda, MD',
#   'GlobalResourceSolutions',
#   'Research Data Analyst-Data Manager',
#   'EMPTY'],
#  ['Rockville, MD', 'EMD', 'Scientist - Virologist', 'EMPTY'],
#  ['Rockville, MD',
#   'GeisingerHealthSystem',
#   'BIOINFORMATICS RESEARCH SCIENTIST',
#   'EMPTY'],
#  ['Laurel, MD',
#   'BrainTrustHoldings',
#   'Machine Learning & Analytics Developer',
#   'EMPTY'],
#  ['Washington, DC',
#   'IFPRI(InternationalFoodPolicyResearchInstitut...',
#   'Senior Research Assistant / Research Analyst',
#   'EMPTY'],
#  ['Bethesda, MD',
#   'PharmeritInternational',
#   'Scientist - Modeling and Meta-Analysis',
#   'EMPTY'],
#  ['Washington, DC',
#   "Children'sNationalMedicalCenter",
#   'STAFF SCIENTIST I',
#   'EMPTY'],
#  ['Arlington, VA',
#   'BoozAllenHamilton',
#   'Defense Research Analyst, Mid',
#   'EMPTY'],
#  ['Alexandria, VA 22315',
#   'StrategicManagement',
#   'Healthcare Statistical Analyst Internship',
#   'EMPTY'],
#  ['McLean, VA 22101',
#   'EngilityCorporation',
#   'Mid-level Operations Research/Data Analyst',
#   'EMPTY'],
#  ['Washington, DC 20005 (Logan Circle area)',
#   'AmericanRivers',
#   'Science & Economics Intern',
#   'EMPTY'],
#  ['Laurel, MD',
#   'TheJohnsHopkinsAppliedPhysicsLaboratory',
#   'Machine Learning Developer',
#   'EMPTY'],
#  ['Washington, DC',
#   'JobspringPartners',
#   'Machine Learning Data Engineer',
#   '$100,000 - $150,000 a year'],
#  ['Washington, DC',
#   'Finra',
#   'Research Analyst - Office of Emerging Regulatory Issues - Washington, DC',
#   'EMPTY'],
#  ['Washington, DC',
#   'Harnham',
#   'SVP Big Data and Analytics',
#   '$250,000 a year'],
#  ['Bethesda, MD',
#   'MedicalScience&Computing,Inc.',
#   'Computational Biology Specialist',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'GrantThornton',
#   'Data Scientist',
#   'EMPTY'],
#  ['Washington, DC 20037 (Foggy Bottom area)',
#   'AssociationofAmericanMedicalColleges',
#   'Senior Research and Data Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'BoozAllenHamilton',
#   'Criminal Justice Research Analyst, Lead',
#   'EMPTY'],
#  ['Bethesda, MD',
#   'MedicalScience&Computing,Inc.',
#   'Computational Biology Specialist',
#   'EMPTY'],
#  ['Alexandria, VA', 'TheTauriGroupLLC', 'Intelligence Analyst SME', 'EMPTY'],
#  ['Bethesda, MD',
#   'MedicalScience&Computing,Inc.',
#   'Computational Genomics Specialist',
#   'EMPTY'],
#  ['Washington, DC', 'IHSMarkit', 'Senior Data Analyst', 'EMPTY'],
#  ['Arlington, VA 22201 (Lyon Village area)',
#   'GeneralDynamicsInformationTechnology',
#   'Operation Research Analyst',
#   'EMPTY'],
#  ['Bethesda, MD',
#   'MedicalScience&Computing,Inc.',
#   'Computational Image Data Analysis Manager',
#   'EMPTY'],
#  ['Washington, DC', 'Cognitio', 'District of Columbia', 'EMPTY'],
#  ['Fairfax, VA 22030',
#   'TetraTech',
#   'Mid-level Environmental Engineer or Scientist',
#   'EMPTY'],
#  ['Alexandria, VA',
#   'RadiantBlueTechnologies,Inc.',
#   'Systems Analyst',
#   'EMPTY'],
#  ['Washington, DC', 'xentitycorporation', 'Geospatial Architect', 'EMPTY'],
#  ['McLean, VA 22101',
#   'EngilityCorporation',
#   'Mid-level Operations Research/Data Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'GeneralAssembly',
#   'Lead Data Science Instructor',
#   'EMPTY'],
#  ['College Park, MD',
#   'UniversityofMaryland',
#   'Post-Doctoral Scientist',
#   '$40,000 - $45,000 a year'],
#  ['Annapolis Junction, MD', 'Raytheon', 'Computer Scientist', 'EMPTY'],
#  ['Washington, DC', 'CentraTechnology', 'DHS Quantitative Analyst', 'EMPTY'],
#  ['Washington, DC',
#   'AcumenLLC',
#   'Data and Policy Analyst - Statistical Programmer',
#   'EMPTY'],
#  ['Chantilly, VA', 'Aret\xc3\xa9Associates', 'Research Scientist', 'EMPTY'],
#  ['Springfield, VA',
#   'BaroneConsulting',
#   'Research Engineer/Scientist Level 3 TS/SCI',
#   'EMPTY'],
#  ['Germantown, MD', 'AECOM', 'Data Management Specialist', 'EMPTY'],
#  ['Washington, DC',
#   'DepartmentoftheNavy,Naval...',
#   'Computer Scientist',
#   'EMPTY'],
#  ['Washington, DC', 'Cognitio', 'Washington', 'EMPTY'],
#  ['Tysons Corner, VA',
#   'PNCBank',
#   'Quantitative Analytics & Model Development Analyst Sr',
#   'EMPTY'],
#  ['Washington, DC',
#   'NationalOlderWorkerCareerCenter',
#   'Scientific Advisory Panel Support',
#   'EMPTY'],
#  ['Gaithersburg, MD 20878', 'Leidos', 'Computer Operator III (NCI)', 'EMPTY'],
#  ['Alexandria, VA',
#   'RadiantBlueTechnologies,Inc.',
#   'Systems Analyst',
#   'EMPTY'],
#  ['Fort Meade, MD',
#   'SemperFortisSolutions,LLC',
#   'Research Analyst II/III',
#   'EMPTY'],
#  ['Gaithersburg, MD 20877', 'GeneDx,Inc', 'R&D Scientist', 'EMPTY'],
#  ['Arlington, VA', 'Vencore', 'Research Scientist/Engineer', 'EMPTY'],
#  ['Springfield, VA',
#   'BaroneConsulting',
#   'Research Engineer/Scientist Level 3 TS/SCI',
#   'EMPTY'],
#  ['Washington, DC 20001 (Shaw area)',
#   'GoodwinProcterLLP',
#   'Research Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'DepartmentoftheNavy,Naval...',
#   'Computer Scientist',
#   'EMPTY'],
#  ['Washington, DC', 'CSRA', 'Operations Research Analyst Sr', 'EMPTY'],
#  ['Washington, DC',
#   'FiscalNote',
#   'Software Engineer, Data Ingestion',
#   'EMPTY'],
#  ['Springfield, VA',
#   'BoozAllenHamilton',
#   'Data Analyst / Collection Manager',
#   'EMPTY'],
#  ['Laurel, MD',
#   'TheJohnsHopkinsAppliedPhysicsLaboratory',
#   'Machine Learning Developer',
#   'EMPTY'],
#  ['Washington, DC',
#   'DepartmentoftheNavy,Naval...',
#   'Operations Research Analyst',
#   'EMPTY'],
#  ['Fort Meade, MD',
#   'SemperFortisSolutions,LLC',
#   'Research Analyst II/III',
#   'EMPTY'],
#  ['Silver Spring, MD 20910',
#   'TheHenryM.JacksonFoundation',
#   'Research Scientist',
#   'EMPTY'],
#  ['Silver Spring, MD',
#   'GeneralDynamicsInformationTechnology',
#   'Consultant Scientist - Defense and Veterans Brain Injury Center (DVBIC)',
#   'EMPTY'],
#  ['Washington, DC',
#   'CSRA',
#   '2017 GRADUATES ONLY! Associate Professional: Science',
#   'EMPTY'],
#  ['Washington, DC',
#   'T3TradingGroupLLC',
#   'Statistical Pairs Trading Positions',
#   'EMPTY'],
#  ['Ballston, VA', 'GreystonesGroup', 'Program Analyst', 'EMPTY'],
#  ['Herndon, VA', 'Deltek,Inc.', 'Research Analyst', 'EMPTY'],
#  ['Washington, DC',
#   'AmericanProgress',
#   'Research Analyst, CAP Action War Room',
#   'EMPTY'],
#  ['Arlington, VA 22203 (Bluemont area)',
#   'HanoverResearch',
#   'Research Analyst -- Market Research',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'GrantThornton',
#   'Data Scientist',
#   'EMPTY'],
#  ['Fort Meade, MD', 'WoodConsulting', 'Computer Scientist', 'EMPTY'],
#  ['McLean, VA',
#   'MitreCorporation',
#   'Big Data Software/Systems Engineer',
#   'EMPTY'],
#  ['Rockville, MD', 'EMD', 'Scientific Associate 2', 'EMPTY'],
#  ['Washington, DC 20005 (Logan Circle area)',
#   'IBM',
#   'Advanced Analytics Data Scientist',
#   'EMPTY'],
#  ['Germantown, MD', 'AECOM', 'Data Management Specialist', 'EMPTY'],
#  ['Columbia, MD 21046', 'MerkleInc.', 'Advanced Analytics - Analyst', 'EMPTY'],
#  ['Washington, DC',
#   'FiscalNote',
#   'Technical Manager, Data Ingestion',
#   'EMPTY'],
#  ['McLean, VA',
#   'CentraTechnology',
#   'Senior Operations Research Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'CSRA',
#   '2017 GRADUATES ONLY! Associate Professional: Science',
#   'EMPTY'],
#  ['Arlington, VA 22203 (Bluemont area)',
#   'HanoverResearch',
#   'Research Analyst -- Consumer Insights',
#   'EMPTY'],
#  ['Washington, DC',
#   'STG,Inc.',
#   'Data Scientist / Database Specialist',
#   'EMPTY'],
#  ['Rockville, MD 20850', 'WESTAT', 'Survey Sampling Statistician', 'EMPTY'],
#  ['Washington, DC',
#   'AmericanProgress',
#   'Research Analyst, CAP Action War Room',
#   'EMPTY'],
#  ['McLean, VA',
#   'BoozAllenHamilton',
#   'Computational Social Scientist',
#   'EMPTY'],
#  ['Fort Meade, MD', 'WoodConsulting', 'Computer Scientist', 'EMPTY'],
#  ['Gaithersburg, MD 20878',
#   'TheScientificConsultingGroup,Inc.',
#   'Behavioral and Social Sciences Research Analyst',
#   'EMPTY'],
#  ['Greenbelt, MD',
#   'GlobalScience&Technology,Inc.',
#   'HPC Science Programmer',
#   'EMPTY'],
#  ['Gaithersburg, MD',
#   'LifeTimeFitness',
#   'Ultimate Hoops Statistician',
#   'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'KPMG',
#   'Data Scientist - Government Engagements',
#   'EMPTY'],
#  ['Washington, DC',
#   'AmericanRedCross',
#   'Analyst II, Marketing Research & Planning (Telecommute)',
#   'EMPTY'],
#  ['Suitland, MD',
#   'ParsonsCorporation',
#   'Modeling and Simulation Analyst (EO/IR)',
#   'EMPTY'],
#  ['Fort Belvoir, VA', 'ANSER', 'Project Research Analyst', 'EMPTY'],
#  ['Arlington, VA 22201 (Lyon Village area)',
#   'CNACorp.',
#   'Research Analyst',
#   'EMPTY'],
#  ['Fort Meade, MD',
#   'UnifiedBusinessTechnologies,Inc.',
#   'Research Analyst (CONUS); Premium Pay,Per Diem,TDY encouraged',
#   'EMPTY'],
#  ['Arlington, VA',
#   'ApogeeIntegration,LLC',
#   'Statistician (Secret Clearance)',
#   'EMPTY'],
#  ['Rockville, MD', 'EMD', 'Scientific Associate 2', 'EMPTY'],
#  ['Washington, DC', 'Cognitio', 'District of Columbia', 'EMPTY'],
#  ['Washington, DC', 'xentitycorporation', 'Geospatial Architect', 'EMPTY'],
#  ['Suitland, MD',
#   'ParsonsCorporation',
#   'Modeling and Simulation Analyst (EO/IR)',
#   'EMPTY'],
#  ['Tysons Corner, VA', 'PrevalentInc.', 'Risk Analyst', 'EMPTY'],
#  ['McLean, VA',
#   'CentraTechnology',
#   'Senior Operations Research Analyst',
#   'EMPTY'],
#  ['Fort Meade, MD',
#   'UnifiedBusinessTechnologies,Inc.',
#   'Research Analyst (CONUS); Premium Pay,Per Diem,TDY encouraged',
#   'EMPTY'],
#  ['Fulton, MD', 'Consultants2Go', 'Lead Data Scientist - Healthcare', 'EMPTY'],
#  ['Bethesda, MD 20813', 'Leidos', 'Bioinformatics Analyst (NCI)', 'EMPTY'],
#  ['Washington, DC',
#   'yomdleinc.',
#   'Machine Learning Research Engineer',
#   'EMPTY'],
#  ['Washington, DC 20007 (Georgetown area)',
#   'USNews&WorldReport',
#   'Health Data Analyst',
#   'EMPTY'],
#  ['Fairfax, VA', 'BlittCapital', 'Research & Insight Analyst Intern', 'EMPTY'],
#  ['Alexandria, VA 22314 (Southwest Quadrant area)',
#   'TelemetAmerica,Inc.',
#   'Research Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'DITInc',
#   'OCTO- Research Analyst -Sr-Data Curation (494099)',
#   'EMPTY'],
#  ['Washington, DC',
#   'ILSIHealthandEnvironmentalSciencesInstitute(...',
#   'SCIENTIFIC PROGRAM ASSOCIATE',
#   'EMPTY'],
#  ['Washington, DC',
#   'SoteraDefenseSolutions,Inc.',
#   'Research Scientist, Senior',
#   'EMPTY'],
#  ['Arlington, VA', 'QuantechServices', 'Policy Analyst - SAFTAS III', 'EMPTY'],
#  ['Washington, DC',
#   'ILSIHealthandEnvironmentalSciencesInstitute(...',
#   'SCIENTIFIC PROGRAM ASSOCIATE',
#   'EMPTY'],
#  ['Washington, DC', 'CSRA', 'Operations Research Analyst Sr', 'EMPTY'],
#  ['Washington, DC',
#   'TheCadmusGroup,Inc.',
#   'Exercise Research Analyst',
#   'EMPTY'],
#  ['Washington, DC',
#   'FawkesIDM',
#   'Research Analyst - Law Firm',
#   '$70,000 - $80,000 a year'],
#  ['Chantilly, VA',
#   'NovelApplicationsofVitalInformation',
#   'Research Analyst - Intelligence/Operations',
#   'EMPTY'],
#  ['Alexandria, VA',
#   'TULKllc',
#   'Research Development Engineer/Scientist',
#   '$160,000 a year'],
#  ['Washington, DC', 'CEB', 'Research Analyst - Enterprise Research', 'EMPTY'],
#  ['Washington, DC 20003 (Capitol Hill area)',
#   'AlionScienceandTechnology',
#   'Junior Business Development Research Analyst',
#   'EMPTY'],
#  ['McLean, VA', 'Digicon', 'Bioinformatics Scientist', 'EMPTY'],
#  ['Fort Washington, MD', 'Leger', 'Research Analyst', 'EMPTY'],
#  ['Arlington, VA 22209 (Radnor-Ft Myer Heights area)',
#   'FBR&Co.',
#   '2017 Summer Analyst, Equity Research',
#   'EMPTY'],
#  ['McLean, VA 22108', 'Leidos', 'Data Scientist', 'EMPTY'],
#  ['Washington, DC 20036 (Downtown area)',
#   'Oceana',
#   'Marine Economist, Science & Strategy Division',
#   'EMPTY'],
#  ['Washington, DC', 'CEB', 'Research Analyst - Enterprise Research', 'EMPTY'],
#  ['Greenbelt, MD',
#   'ScienceSystemandApplications,Inc.',
#   'Signal Processing Data Analyst',
#   'EMPTY'],
#  ['Washington, DC', 'TheWorldBankGroup', 'Data Scientist', 'EMPTY'],
#  ['Fairfax, VA 22030',
#   'BaileyInformationTechnologyConsultants,LLC',
#   'Sr. Algorithm Scientist',
#   'EMPTY'],
#  ['Fort Belvoir, VA', 'EOIRTechnologies', 'Image - Video Analyst', 'EMPTY'],
#  ['Springfield, VA',
#   'IntegrityApplicationsIncorporated',
#   'GEOINT Spectral Program Scientist',
#   'EMPTY'],
#  ['Washington, DC',
#   'ECSFederalLLC',
#   'Junior Operations Research Analyst',
#   'EMPTY'],
#  ['McLean, VA', 'Vencore', 'Research Analyst III', 'EMPTY'],
#  ['Washington, DC 20005 (Logan Circle area)',
#   '\xc3\x98ptimusConsulting',
#   'Digital Strategy Intern',
#   'EMPTY'],
#  ['Alexandria, VA',
#   'E3Federal',
#   'Research Stakeholder Coordination Analyst DODP12',
#   'EMPTY'],
#  ['College Park, MD',
#   'UniversityofMaryland',
#   'Post-Doctoral Associate',
#   'EMPTY'],
#  ['Germantown, MD', 'QIAGEN', 'Scientist I', 'EMPTY'],
#  ['Washington, DC',
#   'SoteraDefenseSolutions,Inc.',
#   'Research Scientist, Senior',
#   'EMPTY'],
#  ['Arlington, VA 22201 (Lyon Village area)',
#   'CNACorp.',
#   'Research Analyst - Economist',
#   'EMPTY'],
#  ['Fort Meade, MD',
#   'BoozAllenHamilton',
#   'Operations / Mathematical Modeling Research Analyst, Mid',
#   'EMPTY'],
#  ['Arlington, VA 22209 (Radnor-Ft Myer Heights area)',
#   'FBR&Co.',
#   '2017 Summer Analyst, Equity Research',
#   'EMPTY'],
#  ['Chevy Chase, MD',
#   'GEICO',
#   'Strategic Modeling & Statistical Analyst',
#   'EMPTY'],
#  ['Arlington, VA',
#   'Invincea',
#   'Research Engineer/Scientist \xe2\x80\x93 Information Visualization and UI Design',
#   'EMPTY'],
#  ['Washington, DC',
#   'STG,Inc.',
#   'Data Scientist / Database Specialist',
#   'EMPTY'],
#  ['Herndon, VA 20170', 'Raytheon', 'Web Based Research Analyst', 'EMPTY'],
#  ['Washington, DC',
#   'TheTauriGroup',
#   'Intelligence Analyst \xe2\x80\x93 Multiple Levels',
#   'EMPTY'],
#  ['Bethesda, MD 20814',
#   'CysticFibrosisFoundation',
#   'Community Research Analyst',
#   'EMPTY'],
#  ['Fairfax, VA 22030',
#   'BaileyInformationTechnologyConsultants,LLC',
#   'Sr. Algorithm Scientist',
#   'EMPTY'],
#  ['Arlington, VA', 'SoteraDefenseSolutions,Inc.', 'Data Scientist', 'EMPTY'],
#  ['Bethesda, MD 20813',
#   'Leidos',
#   'Brain Trauma Research Fellows (Neuroscientist)',
#   'EMPTY'],
#  ['Rockville, MD', 'USPharmacopeia', 'Scientist IV/V', 'EMPTY'],
#  ['Arlington, VA',
#   'BennettAerospaceInc.',
#   'Mathematician / Statistician',
#   'EMPTY'],
#  ['Fort Meade, MD',
#   'BoozAllenHamilton',
#   'Operations / Mathematical Modeling Research Analyst, Mid',
#   'EMPTY'],
#  ['Reston, VA 20190',
#   'CyberspaceSolutionsLLC',
#   'Mid-Level Open Source Research Analyst',
#   'EMPTY'],
#  ['Rockville, MD',
#   'NationalCenterforAdvancingTranslationalScienc...',
#   'Medicinal Chemists',
#   'EMPTY'],
#  ['Arlington, VA',
#   'BoozAllenHamilton',
#   'Military Operations Research Analyst, Mid',
#   'EMPTY'],
#  ['Reston, VA', 'MOJA', 'Software Engineer', 'EMPTY'],
#  ['Springfield, VA',
#   'MacAulay-Brown,Inc.(MacB)',
#   'Statistician/ Imagery Science Support',
#   'EMPTY'],
#  ['Alexandria, VA',
#   'E3Federal',
#   'Research Stakeholder Coordination Analyst DODP12',
#   'EMPTY'],
#  ['Washington, DC 20003 (Capitol Hill area)',
#   'AlionScienceandTechnology',
#   'Junior Business Development Research Analyst',
#   'EMPTY'],
#  ['Herndon, VA 20170', 'Raytheon', 'Web Based Research Analyst', 'EMPTY'],
#  ['Arlington, VA 22201 (Lyon Village area)',
#   'CNACorp.',
#   'Research Analyst - Economist',
#   'EMPTY'],
#  ['Bethesda, MD 20814',
#   'CysticFibrosisFoundation',
#   'Community Research Analyst',
#   'EMPTY'],
#  ['Greenbelt, MD',
#   'ASRCFederal',
#   'Senior Project Support Specialist',
#   'EMPTY'],
#  ['Reston, VA', 'ReedElsevier', 'Court Research Analyst', 'EMPTY'],
#  ['Arlington, VA',
#   'RedGateGroup',
#   'IT Requirements/ Data Scientist -OUSDI-HCMO-DCIPS',
#   'EMPTY'],
#  ['McLean, VA', 'CapitalOne', 'Machine Learning Engineer', 'EMPTY'],
#  ['Washington, DC',
#   'NextCenturyCorporation',
#   'Back End Software Engineer',
#   'EMPTY'],
#  ['Rockville, MD',
#   'GlaxoSmithKline',
#   'Expert Scientist, Downstream Technical R & D (1)',
#   'EMPTY'],
#  ['Germantown, MD', 'QIAGEN', 'Scientist I', 'EMPTY'],
#  ['Greenbelt, MD',
#   'KBRWyle',
#   'Scientific Software Developer (Greenbelt, MD)',
#   'EMPTY'],
#  ['Washington, DC', 'TheAdvisoryBoardCompany', 'Software Engineer', 'EMPTY'],
#  ['Washington, DC', 'Arcadis:US', 'Field Technician', 'EMPTY'],
#  ['Arlington, VA',
#   'Invincea',
#   'Research Engineer/Scientist \xe2\x80\x93 Information Visualization and UI Design',
#   'EMPTY'],
#  ['Washington, DC',
#   'xentitycorporation',
#   'Independent Consultant - Government Solution Architect',
#   'EMPTY'],
#  ['Washington, DC',
#   'ECSFederalLLC',
#   'Junior Operations Research Analyst',
#   'EMPTY'],
#  ['Washington, DC', 'BoozAllenHamilton', 'Data Scientist', 'EMPTY'],
#  ['College Park, MD 20740',
#   'BoozAllenHamilton',
#   'Human Language Translation Research Analyst',
#   'EMPTY'],
#  ['Arlington, VA',
#   'BAESystems',
#   'Senior Principal Machine Learning Research Engineer',
#   'EMPTY'],
# ...
#   '$160,000 a year'],
#  ['Chicago, IL',
#   'NextCapital',
#   'Product Design & Development Intern',
#   'EMPTY'],
#  ['Chicago, IL',
#   'IllinoisTechnologyAssociation',
#   'Capital One - Director of Data Science',
#   'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'IT Programmer 2', 'EMPTY'],
#  ['Chicago, IL',
#   'NorthwesternUniversity',
#   'Research Project Coordinator',
#   'EMPTY'],
#  ['Chicago, IL', 'NorthwesternUniversity', 'Developer', 'EMPTY'],
#  ['Chicago, IL',
#   'Morningstar',
#   'Analyst, Passive Strategies, Research',
#   'EMPTY'],
#  ['Chicago, IL', 'MotorolaMobility', 'Director of Machine Learning', 'EMPTY'],
#  ['Chicago, IL',
#   'InContextSolutions',
#   'Market Research Analyst (Entry Level)',
#   'EMPTY'],
#  ['Chicago, IL 60642 (Portage Park area)',
#   'TurboTitleLoan.com',
#   'Data Analyst',
#   'EMPTY'],
#  ['Chicago, IL',
#   'GeneralAssembly',
#   'Part-time Data Science Instructor',
#   'EMPTY'],
#  ['Chicago, IL',
#   'WorkbridgeAssociates',
#   'Data Engineer (Python, Spark, Scala, Hadoop)',
#   '$45 - $80 an hour'],
#  ['Chicago, IL 60610 (Near North Side area)',
#   'JobspringPartners',
#   'Principal Data Scientist',
#   '$160,000 a year'],
#  ['Chicago, IL 60607 (Near West Side area)',
#   'EmergeMedia',
#   'Data Scientist Intern',
#   'EMPTY'],
#  ['Chicago, IL', 'Mintel', 'Senior Research Analyst', 'EMPTY'],
#  ['Chicago, IL 60607 (Near West Side area)',
#   'physIQ',
#   'QA / Support Engineer',
#   'EMPTY'],
#  ['Chicago, IL', 'Cars.com', 'Principal, Machine Learning', 'EMPTY'],
#  ['Oak Brook, IL', 'Exelon', 'Sr Quantitative Analyst UOF - E03', 'EMPTY'],
#  ['Chicago, IL 60604 (Loop area)',
#   'CNAInsurance',
#   'Actuarial Statistical Reporting Analyst',
#   'EMPTY'],
#  ['Chicago, IL',
#   'S.C.International',
#   'Statistical Analyst -- Health-7444',
#   '$80,000 a year'],
#  ['Chicago, IL', 'SiliconValleyDataScience', 'Rainmaker', 'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyAssociates',
#   'Quantitative Research Analyst',
#   '$150,000 a year'],
#  ['Chicago, IL 60606 (Loop area)',
#   'Technomic,Inc.',
#   'Research Analyst (Mixed Methods)',
#   'EMPTY'],
#  ['Chicago, IL',
#   'McKinsey&Company',
#   'Product Manager - New Ventures Technology Emerging Solutions',
#   'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyAssociates',
#   'Quantitative Risk Analyst',
#   '$100,000 a year'],
#  ['Chicago, IL', 'Mintel', 'Senior Research Analyst', 'EMPTY'],
#  ['Chicago, IL 60607 (Near West Side area)',
#   'physIQ',
#   'QA / Support Engineer',
#   'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyBanking&FinancialServices',
#   'Quantitative Analyst',
#   '$100,000 a year'],
#  ['Evanston, IL', 'Nielsen', 'Optimization Specialist', 'EMPTY'],
#  ['Chicago, IL', 'SiliconValleyDataScience', 'Rainmaker', 'EMPTY'],
#  ['Chicago, IL', 'RushUniversityMedicalCenter', 'Sr Statistician', 'EMPTY'],
#  ['Chicago, IL', 'Starcom', 'Analyst, Research', 'EMPTY'],
#  ['Chicago, IL',
#   'McKinsey&Company',
#   'Product Manager - New Ventures Technology Emerging Solutions',
#   'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyAssociates',
#   'Quantitative Research Analyst',
#   '$150,000 a year'],
#  ['Evanston, IL', 'Nielsen', 'Optimization Specialist', 'EMPTY'],
#  ['Chicago, IL', 'BlueCrossBlueShieldAssociation', 'Intern - NDW', 'EMPTY'],
#  ['Chicago, IL', 'Uptake', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL', 'EmergeMedia', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)', 'Tempus', 'Variant Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'JacksonNationalLifeInsuranceCompany',
#   'Data Scientist, Advanced Data Analytics',
#   'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'TheBostonConsultingGroup',
#   'Knowledge Analyst - Automation & Programming',
#   'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)', 'Vizient,Inc.', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'Hyatt',
#   'Sr. Data Scientist \xe2\x80\x93 Analytics',
#   'EMPTY'],
#  ['Chicago, IL 60611 (Near North Side area)',
#   'Cushman&Wakefield',
#   'Research Analyst',
#   'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'Data Manager', 'EMPTY'],
#  ['Chicago, IL', 'Uptake', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyBanking&FinancialServices',
#   'Quantitative Risk Analyst',
#   '$90,000 a year'],
#  ['Chicago, IL', 'Kollmorgen', 'Customer DBS Leader', 'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'TrunkClub',
#   'Senior Data Scientist (Chicago)',
#   'EMPTY'],
#  ['Chicago, IL', 'GeneralAssembly', 'Lead Data Science Instructor', 'EMPTY'],
#  ['Chicago, IL', 'Amyx', 'SEC Financial Computer Scientist (Python)', 'EMPTY'],
#  ['Chicago, IL',
#   'NorthernTrustCorp.',
#   'Fixed Income Municipal Research Analyst',
#   'EMPTY'],
#  ['Chicago, IL', 'AmericanFamilyInsurance', 'Data Scientist II', 'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'Data Manager', 'EMPTY'],
#  ['Chicago, IL', 'GeneralAssembly', 'Lead Data Science Instructor', 'EMPTY'],
#  ['Chicago, IL',
#   'IRI',
#   'Consumer Attitudes & Segmentation Analyst \xe2\x80\x93 Consumer and Shopper Marketing',
#   'EMPTY'],
#  ['Chicago, IL', 'CapitalOne', 'Director of Data Science', 'EMPTY'],
#  ['Melrose Park, IL',
#   'FreseniusKabi',
#   'ASSOCIATE SCIENTIST (MP00744)',
#   'EMPTY'],
#  ['Park Ridge, IL 60068',
#   'AMERICANASSOCIATIONOFNURSEANESTHETISTS',
#   'Quality Research Analyst',
#   'EMPTY'],
#  ['Chicago, IL 60611 (Near North Side area)',
#   'Cushman&Wakefield',
#   'Research Analyst',
#   'EMPTY'],
#  ['Chicago, IL',
#   'Hyatt',
#   'Sr. Data Scientist \xe2\x80\x93 Analytics',
#   'EMPTY'],
#  ['Chicago, IL', 'IRI', 'Director - Sr Research Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyBanking&FinancialServices',
#   'Quantitative Risk Analyst',
#   '$90,000 a year'],
#  ['Chicago, IL', 'OneviewHealthcare,plc', 'Outcomes Analyst', 'EMPTY'],
#  ['Chicago, IL', 'PowerReviews', 'Business Intelligence Developer', 'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'TrunkClub',
#   'Senior Data Scientist (Chicago)',
#   'EMPTY'],
#  ['Chicago, IL',
#   'Epsilon',
#   'Intern - Data Science, Computer Science, Optimization, Machine Learning, Analytics and Graph Theory',
#   'EMPTY'],
#  ['Chicago, IL', 'CivisAnalytics', 'Lead Data Architect', 'EMPTY'],
#  ['Chicago, IL', 'Starcom', 'Senior Analyst, Research', 'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'ConversantMedia',
#   'Data Visualization Scientist',
#   'EMPTY'],
#  ['Chicago, IL',
#   'WorkbridgeAssociates',
#   'Lead Data Scientist (Data Visualization)',
#   '$110,000 - $135,000 a year'],
#  ['Chicago, IL',
#   'Ann&RobertH.LurieChildren\xe2\x80\x99sHospitalofChica...',
#   'Post-Doctoral Associate, Human Molecular Genetics',
#   'EMPTY'],
#  ['Chicago, IL', 'GelberGroup', 'Statistical Arbitrage Trader', 'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)',
#   'UnitedAirlinesInc.',
#   'Big Data Manager',
#   'EMPTY'],
#  ['Chicago, IL',
#   'NaturalResourceTechnology',
#   'Field Hydrogeologist -Chicago or Milwaukee',
#   'EMPTY'],
#  ['Chicago, IL', 'AllianceData', 'Data Visualization Scientist', 'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'Tempus',
#   'Computational Biologist- Tumor Biology',
#   'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)',
#   'TheLaSalleNetwork',
#   'Market Research Analyst',
#   'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)', 'Prosperoware', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'NationalOpinionResearchCenter(NORC)',
#   'Center for Excellence in Survey Research - Multiple Opportunities',
#   'EMPTY'],
#  ['Oakbrook Terrace, IL 60181',
#   'InteQ',
#   'SENIOR STATISTICAL ANALYST',
#   'EMPTY'],
#  ['Willowbrook, IL 60527', 'Clorox', 'Technician/Sr. Technician', 'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'ConversantMedia',
#   'Data Visualization Scientist',
#   'EMPTY'],
#  ['Chicago, IL',
#   'T3TradingGroupLLC',
#   'Statistical Pairs Trading Position',
#   'EMPTY'],
#  ['Chicago, IL',
#   'IntegratedManagementResources,LLC',
#   'jr quantitative analyst',
#   'EMPTY'],
#  ['Chicago, IL',
#   'IpsosNorthAmerica',
#   'Market Research Analyst - Analyst Development Program',
#   'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)',
#   'UnitedAirlinesInc.',
#   'Big Data Manager',
#   'EMPTY'],
#  ['Chicago, IL', 'AllianceData', 'Data Visualization Scientist', 'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)', 'Prosperoware', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'Ann&RobertH.LurieChildren\xe2\x80\x99sHospitalofChica...',
#   'Post-Doctoral Associate, Human Molecular Genetics',
#   'EMPTY'],
#  ['Chicago, IL', 'CompunnelSoftwareGroup', 'Scientist', 'EMPTY'],
#  ['Chicago, IL', 'Harnham', 'Lead Data Scientist', '$250,000 a year'],
#  ['Chicago, IL', 'EdisonEnergySupportServices2LLC', 'Data Scientist', 'EMPTY'],
#  ['Lombard, IL', 'ChangeHealthcare', 'Statistical Data Specialist', 'EMPTY'],
#  ['Chicago, IL', 'Mintel', 'Research Analyst - Beverage', 'EMPTY'],
#  ['Chicago, IL',
#   'TheFederalHomeLoanBankofChicago',
#   'Rotational Analyst (Quantitative Track)',
#   'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'Tempus',
#   'Molecular Geneticist in Oncology',
#   'EMPTY'],
#  ['Chicago, IL', 'BMOFinancialGroup', 'Quantitative Analyst', 'EMPTY'],
#  ['Chicago, IL 60602 (Loop area)',
#   'TruvenHealthAnalytics,Inc.&SimplerConsulting',
#   'Healthcare Research Scientist',
#   'EMPTY'],
#  ['Chicago, IL',
#   'McKinsey&Company',
#   'Product Owner - McKinsey Academy',
#   'EMPTY'],
#  ['Chicago, IL',
#   'McKinsey&Company',
#   'Technology Operations Lead - New Ventures',
#   'EMPTY'],
#  ['Oakbrook Terrace, IL', 'Outerwall', 'Data Scientist, Marketing', 'EMPTY'],
#  ['Chicago, IL', 'Hirewell', 'Open Source Geniuses', '$120,000 a year'],
#  ['Deerfield, IL', 'Baxter', 'Research Scientist I', 'EMPTY'],
#  ['Chicago, IL',
#   '10xGenomics',
#   'Field Application Scientist - Chicago',
#   'EMPTY'],
#  ['Chicago, IL',
#   'RushUniversityMedicalCenter',
#   'Sr Research Reg Ops Analyst',
#   'EMPTY'],
#  ['Northbrook, IL 60062',
#   'Walgreens',
#   'Associate Packaging Scientist',
#   'EMPTY'],
#  ['Chicago, IL',
#   'NextCapital',
#   'Financial Methodology Product Designer',
#   'EMPTY'],
#  ['Chicago, IL 60647 (Logan Square area)',
#   'Nielsen',
#   'Junior Software Engineer',
#   'EMPTY'],
#  ['Chicago, IL', 'Optiver', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL', 'Medix', 'Raw Material Information Specialist', 'EMPTY'],
#  ['Oak Brook, IL', 'ACHFoodCompanies', 'Food Scientist', 'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'Tempus',
#   'Computational Biologists- Pharmacogenomics',
#   'EMPTY'],
#  ['Deerfield, IL',
#   'Walgreens',
#   'Search Intelligence Manager (Data Scientist)',
#   'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'CroweHorwath',
#   'Data Scientist/Modeling - Applied Technology - 13350',
#   'EMPTY'],
#  ['Chicago, IL',
#   'AnalyticRecruiting',
#   'Quantitative Analyst Fixed Income',
#   'EMPTY'],
#  ['Downers Grove, IL',
#   'HAVILogistics',
#   'Qualitative Research Analyst, Consumer Insights',
#   'EMPTY'],
#  ['Chicago, IL 60654 (Loop area)',
#   'Groupon',
#   'Data Scientist - Groupon Getaways',
#   'EMPTY'],
#  ['Chicago, IL', 'CivisAnalytics', 'Lead Data Engineer', 'EMPTY'],
#  ['Chicago, IL', 'BuzzFeed', 'Strategic Planning Director (Chicago)', 'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'ConversantMedia',
#   'Data Scientist',
#   'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'DevOps Engineer', 'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'Research Specialist 2', 'EMPTY'],
#  ['Chicago, IL', 'Epsilon', 'Data Scientist', 'EMPTY'],
#  ['Des Plaines, IL',
#   'ABBOTTLABORATORIES',
#   'Post Doc Industry Scientist',
#   'EMPTY'],
#  ['Downers Grove, IL',
#   'HAVILogistics',
#   'Qualitative Research Analyst, Consumer Insights',
#   'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'Senior Bioinformatician', 'EMPTY'],
#  ['Chicago, IL', 'Mintel', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL', 'NorthwesternUniversity', 'Senior Developer', 'EMPTY'],
#  ['Deerfield, IL',
#   'Walgreens',
#   'Search Intelligence Manager (Data Scientist)',
#   'EMPTY'],
#  ['Chicago, IL', 'PlanetPharma', 'QC Chemist', 'EMPTY'],
#  ['Chicago, IL',
#   'HillardHeintze',
#   'Specialist - Senior Research Scientist',
#   'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyAssociates',
#   'Research Analyst-Clearing House',
#   '$90,000 a year'],
#  ['Chicago, IL', 'WorkbridgeAssociates', 'CTO', '$90,000 - $120,000 a year'],
#  ['Chicago, IL', 'Epsilon', 'Data Scientist', 'EMPTY'],
#  ['Wheaton, IL 60187',
#   'PlanningResourcesInc.',
#   'Wetland Ecologist Botanist',
#   'EMPTY'],
#  ['Chicago, IL',
#   'WorkbridgeAssociates',
#   'Deep Learning/Neural Networking Expert (Python, Theano, TensorFlow)',
#   '$40 - $90 an hour'],
#  ['Chicago, IL', 'Mintel', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'MetropolitanWaterReclamationDistrictofGreater...',
#   'Environmental Soil Scientist',
#   '$76,035 - $115,830 a year'],
#  ['Downers Grove, IL', 'AdvocateHealthCare', 'Statistician', 'EMPTY'],
#  ['Chicago, IL',
#   'SmithHanleyAssociates',
#   'Senior Statistical Analyst',
#   '$85,000 a year'],
#  ['Chicago, IL',
#   'WorkbridgeAssociates',
#   'Deep Learning/Neural Networking Expert (Python, TensorFlow, Theano)',
#   '$75 an hour'],
#  ['Chicago, IL',
#   'WorkbridgeAssociates',
#   'Lead Data Scientist (NLP)',
#   '$135,000 a year'],
#  ['Chicago, IL', 'NorthwesternUniversity', 'Senior Developer', 'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'CroweHorwath',
#   'Data Analysis Manager',
#   'EMPTY'],
#  ['Deerfield, IL', 'BeaconHillPharma', 'PV Scientist', 'EMPTY'],
#  ['Glendale Heights, IL', 'KronosFoodsCorp.', 'R&D Bakery Scientist', 'EMPTY'],
#  ['Chicago, IL', 'CivisAnalytics', 'Chief Technology Officer', 'EMPTY'],
#  ['Chicago, IL', 'UniversityofChicago', 'DevOps Engineer', 'EMPTY'],
#  ['Chicago, IL', 'HERE', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL', 'PlanetPharma', 'QC Chemist', 'EMPTY'],
#  ['Chicago, IL', 'FirstSoftSolutions[Direct]', 'Data Scientist', 'EMPTY'],
#  ['Downers Grove, IL 60515',
#   'HAVIGlobalSolutions',
#   'Qualitative Research Analyst, Consumer Insights',
#   'EMPTY'],
#  ['Chicago, IL',
#   'AllianceData',
#   'Intern - Data Science, Computer Science, Optimization, Machine Learning, Analytics and Graph Theory',
#   'EMPTY'],
#  ['Chicago, IL',
#   'NorthwesternUniversity',
#   'Postdoctoral Fellow in Stem Cell Biology and Pharmacogenomics',
#   '$47,484 a year'],
#  ['Chicago, IL 60654 (Loop area)', 'Tempus', 'Scheduler / Assistant', 'EMPTY'],
#  ['South Holland, IL',
#   'Kollmorgen',
#   'Senior Accounts Payable Clerk - Rotterdam area',
#   'EMPTY'],
#  ['Chicago, IL',
#   'NorthwesternUniversity',
#   'Post Doctoral Fellow (Trainee)',
#   'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'ZacksInvestmentResearch',
#   'Data Scientist- Stock Market Applications',
#   'EMPTY'],
#  ['Chicago, IL', 'Morningstar', 'Manager Research Analyst', 'EMPTY'],
#  ['Chicago, IL',
#   'IpsosNorthAmerica',
#   'Custom Health - Research Analyst',
#   'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)',
#   'MarquetteAssociatesInc',
#   'Senior Research Analyst ? Private Equity',
#   'EMPTY'],
#  ['Chicago, IL 60661 (Near West Side area)',
#   'Exponent',
#   'Manager/Senior Manager',
#   'EMPTY'],
#  ['Chicago, IL',
#   'SmithHanleyAssociates',
#   'Senior Statistical Analyst',
#   '$85,000 a year'],
#  ['Glendale Heights, IL', 'KronosFoodsCorp.', 'R&D Bakery Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'UniversityofChicago',
#   'Plant Growth Facilities Research Technician',
#   'EMPTY'],
#  ['Chicago, IL',
#   'HuxleyAssociates',
#   'Research Analyst-Clearing House',
#   '$90,000 a year'],
#  ['Chicago, IL', 'CivisAnalytics', 'DevOps Engineer', 'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)',
#   'UnitedAirlinesInc.',
#   'Senior Analyst - Statistics and Operations Research',
#   'EMPTY'],
#  ['Chicago, IL', 'ZacksInvestmentManagement', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL 60601 (Loop area)',
#   'iTechUS,Inc.',
#   'Regulatory Submissions Data Standardization/Submisat at Chicago, IL',
#   'EMPTY'],
#  ['Chicago, IL',
#   'TheUniversityofChicagoMedicine',
#   'Director, Data Science & Data Engineering',
#   'EMPTY'],
#  ['Downers Grove, IL 60515',
#   'HAVIGlobalSolutions',
#   'Qualitative Research Analyst, Consumer Insights',
#   'EMPTY'],
#  ['Chicago, IL 60606 (Loop area)',
#   'PressGaneyAssociates,Inc.',
#   'Director, Product Management (Analytics)',
#   'EMPTY'],
#  ['Chicago, IL', 'Fleishman-Hillard', 'Senior Research Analyst', 'EMPTY'],
#  ['Chicago, IL',
#   'VistaConsultingGroup',
#   'Data Scientist - Vista Intelligence Group',
#   'EMPTY'],
#  ['Itasca, IL', 'LaunchPoint', 'Data Scientist', 'EMPTY'],
#  ['Chicago, IL',
#   'JobspringPartners',
#   'Senior Data Engineer with Machine Learning',
#   '$120,000 - $130,000 a year'],
#  ...]

# %% [markdown]
# ### Using the previously created functions to parse out 4 fields - location, title, company and salary. Creating a dataframe from the results with the fields as the columns.

# %%
df = pd.DataFrame(data=results)
df.rename(columns = {0:'Location'}, inplace = True)
df.rename(columns = {1:'Company'}, inplace = True)
df.rename(columns = {2:'Title'}, inplace = True)
df.rename(columns = {3:'Salary'}, inplace = True)

df.head()
# Out:
#                Location            Company  \
# 0           Houston, TX  PlatinumSolutions
# 1           Houston, TX                 HP
# 2           Houston, TX  DavidWeekleyHomes
# 3           Houston, TX          Honeywell
# 4  Sugar Land, TX 77478    LifeTimeFitness
#
#                                 Title                     Salary
# 0               Senior Data Scientist  $80,000 - $120,000 a year
# 1         Ultimate Hoops Statistician                      EMPTY
# 2  Associate Statistical Analyst, HSR                      EMPTY
# 3             Market Research Analyst                      EMPTY
# 4                  Research Scientist                      EMPTY

# %%
def eda(dataframe): 
    print "missing values \n", dataframe.isnull().sum() 
    print "dataframe types \n", dataframe.dtypes
    print "dataframe shape \n", dataframe.shape     
    print "dataframe describe \n", dataframe.describe()
    print "dataframe length =", len(dataframe) 
    print "dataframe Salary unique =", dataframe.Salary.unique()
    for item in dataframe:
        print item
        print dataframe[item].nunique()

# %%
eda(df)
# Out:
# missing values
# Location      0
# Company       0
# Title         0
# Salary      155
# dtype: int64
# dataframe types
# Location    object
# Company     object
# Title       object
# Salary      object
# dtype: object
# dataframe shape
# (5168, 4)
# dataframe describe
#            Location        Company           Title Salary
# count          5168           5168            5168   5013
# unique          655           1942            3323    206
# top     Chicago, IL  BallAerospace  Data Scientist  EMPTY
# freq            287            112             195   4652
# dataframe length = 5168
# dataframe Salary unique = ['$80,000 - $120,000 a year' 'EMPTY' None '$120 an hour' '$43,794 a year'
#  '$105,000 a year' '$46,831 a year' '$40,800 - $79,100 a year'
#  '$66,400 - $99,600 a year' '$65,000 a year' '$60,000 a year'
#  '$110,000 - $140,000 a year' '$100,000 - $150,000 a year'
#  '$65,000 - $80,000 a year' '$40 an hour' '$50,000 a year'
#  '$70,000 - $100,000 a year' '$140,000 a year' '$180,000 - $200,000 a year'
#  '$66,829 - $110,664 a year' '$250,000 a year' '$40,000 - $45,000 a year'
#  '$70,000 - $80,000 a year' '$160,000 a year' '$75,000 - $105,000 a year'
#  '$110,000 - $160,000 a year' '$150,000 a year' '$39,983 - $55,500 a year'
#  '$45,000 - $77,000 a year' '$63,696 - $94,557 a year'
#  '$45,000 - $55,000 a year' '$49,000 - $61,000 a year'
#  '$50,000 - $55,000 a year' '$50,000 - $61,500 a year'
#  '$30,000 - $45,000 a year' '$33,000 - $42,000 a year'
#  '$100,000 - $130,000 a year' '$10 - $15 an hour'
#  '$39,173 - $54,944 a year' '$60,000 - $80,000 a year' '$65 an hour'
#  '$70,000 - $90,000 a year' '$120,000 - $140,000 a year'
#  '$85 - $110 an hour' '$45 - $80 an hour' '$50 - $70 an hour'
#  '$130,000 a year' '$60 - $70 an hour' '$120,000 - $150,000 a year'
#  '$80,000 a year' '$180,000 a year' '$100,000 a year' '$90,000 a year'
#  '$110,000 - $135,000 a year' '$120,000 a year' '$90,000 - $120,000 a year'
#  '$40 - $90 an hour' '$76,035 - $115,830 a year' '$85,000 a year'
#  '$75 an hour' '$135,000 a year' '$47,484 a year'
#  '$120,000 - $130,000 a year' '$28.23 an hour' '$75,000 - $110,000 a year'
#  '$75,000 a year' '$115,000 - $135,000 a year' '$75,000 - $95,000 a year'
#  '$38 an hour' '$24.56 an hour' '$33 an hour' '$90,000 - $150,000 a year'
#  '$225,000 a year' '$175,000 - $250,000 a year' '$52,000 a year'
#  '$130 an hour' '$87,834 - $117,112 a year' '$130,000 - $150,000 a year'
#  '$130,000 - $170,000 a year' '$130,000 - $160,000 a year' '$45 an hour'
#  '$100,000 - $180,000 a year' '$70,000 - $110,000 a year'
#  '$65,000 - $110,000 a year' '$70,286 - $80,829 a year'
#  '$130,000 - $165,000 a year' '$150,000 - $185,000 a year'
#  '$70,286 - $87,295 a year' '$100,000 - $135,000 a year'
#  '$72,000 - $84,000 a year' '$15 an hour' '$57,969 - $62,000 a year'
#  '$70,286 - $81,000 a year' '$120,000 - $200,000 a year' '$155,000 a year'
#  '$70,286 - $88,213 a year' '$105,000 - $125,000 a year'
#  '$180,000 - $220,000 a year' '$32.68 - $35.95 an hour'
#  '$150,000 - $300,000 a year' '$140,000 - $200,000 a year' '$70 an hour'
#  '$59,708 - $65,678 a year' '$59,708 - $72,246 a year'
#  '$68,239 - $80,000 a year' '$78,630 - $103,332 a year'
#  '$110,000 - $250,000 a year' '$102,000 a year' '$80,000 - $100,000 a year'
#  '$100,000 - $110,000 a year' '$80 - $90 a day' '$57,150 a year'
#  '$150,000 - $230,000 a year' '$95,000 - $120,000 a year'
#  '$175,000 - $215,000 a year' '$155,000 - $160,000 a year'
#  '$170,000 a year' '$19 - $21 an hour' '$32 - $35 an hour'
#  '$50,000 - $62,000 a year' '$90,000 - $160,000 a year'
#  '$85,000 - $110,000 a year' '$175,000 a year' '$63,339 - $76,007 a year'
#  '$55,132 - $88,211 a year' '$13.57 an hour' '$4,028 - $5,896 a month'
#  '$16 - $18 an hour' '$12 - $14 an hour' '$95,000 - $127,000 a year'
#  '$100,000 - $170,000 a year' '$97,000 a year' '$40,000 - $60,000 a year'
#  '$76,804 - $100,726 a year' '$70,000 - $85,000 a year' '$55,000 a year'
#  '$73,286 - $86,231 a year' '$42 an hour' '$20 an hour'
#  '$4,372 - $9,683 a month' '$100,000 - $109,000 a year' '$72.41 an hour'
#  '$79,884 - $104,772 a year' '$4,372 - $7,650 a month'
#  '$45,000 - $70,000 a year' '$40,092 - $65,676 a year'
#  '$53,000 - $98,000 a year' '$23,868 - $37,752 a year'
#  '$40,000 - $56,000 a year' '$40,000 - $72,000 a year'
#  '$32,900 - $59,100 a year' '$45,000 - $50,000 a year' '$30,000 a year'
#  '$25 an hour' '$53,900 - $96,900 a year' '$27,400 - $49,400 a year'
#  '$58,600 a year' '$55 an hour' '$24,000 a year' '$30,000 - $32,000 a year'
#  '$48 an hour' '$50 - $55 an hour' '$125,000 - $160,000 a year'
#  '$3,152 - $4,215 a month' '$35,000 a year' '$4,431 - $5,955 a month'
#  '$82,326 - $104,374 a year' '$13.30 - $16.85 an hour'
#  '$155,000 - $165,000 a year' '$2,544 - $3,287 a month'
#  '$2,617 - $3,461 a month' '$3,635 - $4,888 a month'
#  '$3,077 - $4,113 a month' '$2,867 - $3,818 a month'
#  '$2,910 - $3,879 a month' '$2,443 - $3,223 a month'
#  '$2,623 - $3,644 a month' '$80,000 - $90,000 a year' '$33.33 an hour'
#  '$6,250 - $10,833 a month' '$4,166 a month' '$110,000 - $150,000 a year'
#  '$75,000 - $90,000 a year' '$2,813 a month' '$5,400 - $6,500 a month'
#  '$5,259 - $6,941 a month' '$4,000 a month' '$40,000 - $47,000 a year'
#  '$11.75 - $16.00 an hour' '$79,000 a year' '$15 - $25 an hour'
#  '$7,500 a month' '$4,583 a month' '$4,124 - $5,301 a month'
#  '$16.14 an hour' '$6,250 - $8,333 a month' '$7,083 - $9,166 a month'
#  '$2,500 a month' '$8,333 - $10,000 a month' '$5,416 a month'
#  '$3,957 a month' '$45,000 a year' '$22 an hour'
#  '$160,000 - $180,000 a year' '$18 - $22 an hour'
#  '$120,000 - $165,000 a year' '$14 - $18 an hour']
# Location
# 655
# Company
# 1942
# Title
# 3323
# Salary
# 206

# %% [markdown]
# ### The salary information needs some serious cleanup.
#
# 1. Only a small number of the scraped results have salary information.
# 1. Some of the salaries are not yearly but hourly, weekly or monthly, these can't be used without making some large assumptions
# 1. Some of the entries may be duplicates
# 1. The salaries are given as text and usually with ranges.

# %%
df['Salary'].replace(regex=True,inplace=True,to_replace='\$',value='') #Removing '$' character
df['Salary'].replace(regex=True,inplace=True,to_replace=',',value=r'') # Removing ','
df['Salary'].replace(regex=True,inplace=True,to_replace='a year',value='year') #changing 'a year' to just 'year'
df['Salary'].replace(regex=True,inplace=True,to_replace='a month',value='month')#changing 'a month' to 'month'
df['Salary'].replace(regex=True,inplace=True,to_replace='an hour',value='hour')#changing 'an hour' to 'hour'

# %%
df['Salary'].replace('EMPTY', np.NaN, inplace = True) #Changing 'EMPTY' salary values to NaN
df['Salary'].replace('None', np.NaN, inplace= True) #Changing 'None' salary values to NaN
df = df.dropna() #Dropping NaN
df.shape
# Out:
# (361, 4)

# %%
#We wouldn't be able to use the month and hour salary data without making some major assumptions about the results.
#I would prefer to avoid that so I am going to create a new dataframe that only contains the yearly salary data
to_drop = ['month', 'hour'] 
year_df3 = df[~df['Salary'].str.contains('|'.join(to_drop))]

eda(year_df3)
# Out:
# missing values
# Location    0
# Company     0
# Title       0
# Salary      0
# dtype: int64
# dataframe types
# Location    object
# Company     object
# Title       object
# Salary      object
# dtype: object
# dataframe shape
# (254, 4)
# dataframe describe
#            Location               Company                  Title       Salary
# count           254                   254                    254          254
# unique           73                   124                    188          138
# top     Chicago, IL  WorkbridgeAssociates  Senior Data Scientist  160000 year
# freq             34                    16                      7           12
# dataframe length = 254
# dataframe Salary unique = ['80000 - 120000 year' '43794 year' '105000 year' '46831 year'
#  '40800 - 79100 year' '66400 - 99600 year' '65000 year' '60000 year'
#  '110000 - 140000 year' '100000 - 150000 year' '65000 - 80000 year'
#  '50000 year' '70000 - 100000 year' '140000 year' '180000 - 200000 year'
#  '66829 - 110664 year' '250000 year' '40000 - 45000 year'
#  '70000 - 80000 year' '160000 year' '75000 - 105000 year'
#  '110000 - 160000 year' '150000 year' '39983 - 55500 year'
#  '45000 - 77000 year' '63696 - 94557 year' '45000 - 55000 year'
#  '49000 - 61000 year' '50000 - 55000 year' '50000 - 61500 year'
#  '30000 - 45000 year' '33000 - 42000 year' '100000 - 130000 year'
#  '39173 - 54944 year' '60000 - 80000 year' '70000 - 90000 year'
#  '120000 - 140000 year' '130000 year' '120000 - 150000 year' '80000 year'
#  '180000 year' '100000 year' '90000 year' '110000 - 135000 year'
#  '120000 year' '90000 - 120000 year' '76035 - 115830 year' '85000 year'
#  '135000 year' '47484 year' '120000 - 130000 year' '75000 - 110000 year'
#  '75000 year' '115000 - 135000 year' '75000 - 95000 year'
#  '90000 - 150000 year' '225000 year' '175000 - 250000 year' '52000 year'
#  '87834 - 117112 year' '130000 - 150000 year' '130000 - 170000 year'
#  '130000 - 160000 year' '100000 - 180000 year' '70000 - 110000 year'
#  '65000 - 110000 year' '70286 - 80829 year' '130000 - 165000 year'
#  '150000 - 185000 year' '70286 - 87295 year' '100000 - 135000 year'
#  '72000 - 84000 year' '57969 - 62000 year' '70286 - 81000 year'
#  '120000 - 200000 year' '155000 year' '70286 - 88213 year'
#  '105000 - 125000 year' '180000 - 220000 year' '150000 - 300000 year'
#  '140000 - 200000 year' '59708 - 65678 year' '59708 - 72246 year'
#  '68239 - 80000 year' '78630 - 103332 year' '110000 - 250000 year'
#  '102000 year' '80000 - 100000 year' '100000 - 110000 year' '80 - 90 a day'
#  '57150 year' '150000 - 230000 year' '95000 - 120000 year'
#  '175000 - 215000 year' '155000 - 160000 year' '170000 year'
#  '50000 - 62000 year' '90000 - 160000 year' '85000 - 110000 year'
#  '175000 year' '63339 - 76007 year' '55132 - 88211 year'
#  '95000 - 127000 year' '100000 - 170000 year' '97000 year'
#  '40000 - 60000 year' '76804 - 100726 year' '70000 - 85000 year'
#  '55000 year' '73286 - 86231 year' '100000 - 109000 year'
#  '79884 - 104772 year' '45000 - 70000 year' '40092 - 65676 year'
#  '53000 - 98000 year' '23868 - 37752 year' '40000 - 56000 year'
#  '40000 - 72000 year' '32900 - 59100 year' '45000 - 50000 year'
#  '30000 year' '53900 - 96900 year' '27400 - 49400 year' '58600 year'
#  '24000 year' '30000 - 32000 year' '125000 - 160000 year' '35000 year'
#  '82326 - 104374 year' '155000 - 165000 year' '80000 - 90000 year'
#  '110000 - 150000 year' '75000 - 90000 year' '40000 - 47000 year'
#  '79000 year' '45000 year' '160000 - 180000 year' '120000 - 165000 year']
# Location
# 73
# Company
# 124
# Title
# 188
# Salary
# 138

# %%
#Now that we're sure that we only have yearly data I want to remove the string year from the field
year_df3['Salary'].replace(regex=True,inplace=True,to_replace='year',value='')
year_df3.shape
# Out:
# /Users/valeriarozenbaum/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:3554: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# (254, 4)

# %%
#Writing a function that takes a salary string and converts it to a number, averaging a salary range if necessary

def extract_salary(salary_data):
    k = []
    for item in salary_data.split():
        try:
            k.append(float(item))
        except ValueError:
            pass
    if len(k)>1: #If k is longer than 1
        k = (k[0]+k[1])/2 # k equals - k in first position + k in second position, divided by 2
    else:
        k = k[0] #else - single k's are just equal to k's in the first position
    return k

# %%
year_df3['Avg_Salary'] = year_df3['Salary'].apply(extract_salary)
# Out:
# /Users/valeriarozenbaum/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ### Saving the results as CSVs

# %%
year_df2.to_csv('/Users/valeriarozenbaum/Documents/indeed_full_clean2.csv', index=False) #Saving second dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-6d7e0dc582bb> in <module>()
# ----> 1 year_df2.to_csv(path_or_buf='/Users/valeriarozenbaum/Documents/indeed_full_clean2.csv')
#
# NameError: name 'year_df2' is not defined

# %%
year_df3.to_csv('/Users/valeriarozenbaum/Documents/indeed_full_clean3.csv', index=False) #Saving third dataframe

# %%
year_df.to_csv('/Users/valeriarozenbaum/Documents/indeed_full_clean.csv', index=False) #Saving first dataframe

# %% [markdown]
# ### Reading in the data

# %%
year_df = pd.read_csv('/Users/valeriarozenbaum/Documents/indeed_full_clean.csv')#Reading in first dataframe

# %%
year_df2 = pd.read_csv('/Users/valeriarozenbaum/Documents/indeed_full_clean2.csv')#Reading in second dataframe
# Out:
# (255, 5)

# %%
year_df3 = pd.read_csv('/Users/valeriarozenbaum/Documents/indeed_full_clean3.csv') #Reading in third dataframe

# %% [markdown]
# ### Concatinating

# %%
indeed = pd.concat([year_df,year_df2,year_df3]) #concatinating the three dataframes into the final

# %%
indeed.drop_duplicates(keep='first', inplace=True) #dropping duplicate entries

# %%
indeed.shape #Checking the shape of the dataframe. It looks like after dropping the duplicates we are left with
             #493 yearly salary results we can use.
# Out:
# (493, 7)

# %%
#Creating empty lists for city and state data  
city = []
state = []

for row in indeed['Location']:
    try:
        # Split the row by comma and append
        # everything before the comma to city list
        city.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to state list
        state.append(row.split(',')[1])
    # There shouldn't be an issue with the structure but if there is 
    except:
        # append a missing value to city
        city.append(np.NaN)
        # append a missing value to state
        state.append(np.NaN)

# Create two new columns from city and state
indeed['City'] = city
indeed['State'] = state

# %%
# strip away all characters after the last character in the state abbreviation
indeed['State'] = indeed['State'].map(lambda x: str(x)[:3])

# %%
indeed.to_csv('/Users/valeriarozenbaum/Documents/last_complete_indeed_final.csv', index=False) #Saving final dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9ed4f1f7ba25> in <module>()
# ----> 1 indeed.to_csv('/Users/valeriarozenbaum/Documents/last_complete_indeed_final.csv')
#
# NameError: name 'indeed' is not defined

# %% [markdown]
# ## Predicting salaries using Random Forests + Logistic Regression

# %% [markdown]
# ### Loading in the the data of scraped salaries

# %%
indeed = pd.read_csv('/Users/valeriarozenbaum/Documents/last_complete_indeed_final.csv') #reading in the file

# %%
eda(indeed)
# Out:
# missing values
# Avg_Salary    0
# Company       0
# Location      0
# Salary        0
# Title         0
# City          0
# State         0
# dtype: int64
# dataframe types
# Avg_Salary    float64
# Company        object
# Location       object
# Salary         object
# Title          object
# City           object
# State          object
# dtype: object
# dataframe shape
# (493, 7)
# dataframe describe
#           Avg_Salary
# count     493.000000
# mean   105093.612576
# std     46471.402353
# min        85.000000
# 25%     67500.000000
# 50%    100000.000000
# 75%    135000.000000
# max    250000.000000
# dataframe length = 493
# dataframe Salary unique = ['80000 - 120000 year' '43794 year' '105000 year' '46831 year'
#  '40800 - 79100 year' '66400 - 99600 year' '65000 year' '60000 year'
#  '100000 - 150000 year' '50000 year' '140000 year' '66829 - 110664 year'
#  '180000 - 200000 year' '53088 - 92814 year' '250000 year'
#  '40000 - 45000 year' '196000 year' '160000 year' '70000 - 80000 year'
#  '75000 - 105000 year' '110000 - 160000 year' '150000 year'
#  '39983 - 55500 year' '45000 - 77000 year' '63696 - 94557 year'
#  '45000 - 55000 year' '49000 - 61000 year' '50000 - 55000 year'
#  '50000 - 61500 year' '30000 - 45000 year' '33000 - 42000 year'
#  '100000 - 130000 year' '39173 - 54944 year' '60000 - 80000 year'
#  '120000 - 140000 year' '73300 - 114900 year' '130000 year' '125000 year'
#  '180000 year' '80000 year' '90000 year' '120000 year'
#  '90000 - 120000 year' '76035 - 115830 year' '85000 year' '135000 year'
#  '47484 year' '120000 - 130000 year' '75000 - 110000 year'
#  '115000 - 135000 year' '100000 year' '90000 - 150000 year'
#  '175000 - 250000 year' '52000 year' '87834 - 117112 year'
#  '130000 - 150000 year' '130000 - 170000 year' '130000 - 160000 year'
#  '170000 year' '110000 year' '90000 - 170000 year' '70000 - 110000 year'
#  '65000 - 110000 year' '70286 - 80829 year' '130000 - 165000 year'
#  '110000 - 111000 year' '140000 - 180000 year' '150000 - 185000 year'
#  '60000 - 65000 year' '95000 - 130000 year' '100000 - 200000 year'
#  '88305 - 146570 year' '100000 - 120000 year' '100000 - 135000 year'
#  '72000 - 84000 year' '70286 - 81000 year' '155000 year'
#  '70286 - 88213 year' '100000 - 180000 year' '105000 - 125000 year'
#  '180000 - 220000 year' '78630 - 94500 year' '70286 - 83000 year'
#  '59000 - 65000 year' '59708 - 72246 year' '150000 - 300000 year'
#  '78630 - 103332 year' '80000 - 100000 year' '65000 - 80000 year'
#  '57150 year' '80 - 90 a day' '150000 - 230000 year' '95000 - 120000 year'
#  '155000 - 160000 year' '57000 year' '50000 - 62000 year'
#  '85000 - 110000 year' '175000 year' '63339 - 76007 year'
#  '55132 - 88211 year' '95000 - 127000 year' '100000 - 170000 year'
#  '40000 - 60000 year' '76804 - 100726 year' '55000 year'
#  '73286 - 86231 year' '100000 - 109000 year' '60000 - 75000 year'
#  '79884 - 104772 year' '190000 year' '200000 year' '45000 - 70000 year'
#  '40092 - 65676 year' '23868 - 37752 year' '40000 - 56000 year'
#  '40000 - 72000 year' '30000 year' '45000 - 50000 year'
#  '32900 - 59100 year' '53900 - 96900 year' '27400 - 49400 year'
#  '125132 - 161900 year' '58600 year' '24000 year' '30000 - 32000 year'
#  '125000 - 160000 year' '36700 - 55000 year' '120000 - 150000 year'
#  '110000 - 150000 year' '75000 - 90000 year' '40000 - 47000 year'
#  '79000 year' '160000 - 180000 year' '120000 - 165000 year'
#  '75000 - 85000 year' '80000 - 120000 ' '43794 ' '105000 ' '46831 '
#  '40800 - 79100 ' '66400 - 99600 ' '65000 ' '60000 ' '100000 - 150000 '
#  '50000 ' '140000 ' '66829 - 110664 ' '180000 - 200000 ' '53088 - 92814 '
#  '250000 ' '40000 - 45000 ' '196000 ' '160000 ' '70000 - 80000 '
#  '75000 - 105000 ' '110000 - 160000 ' '150000 ' '39983 - 55500 '
#  '45000 - 77000 ' '63696 - 94557 ' '45000 - 55000 ' '49000 - 61000 '
#  '50000 - 55000 ' '50000 - 61500 ' '30000 - 45000 ' '33000 - 42000 '
#  '100000 - 130000 ' '39173 - 54944 ' '60000 - 80000 ' '120000 - 140000 '
#  '73300 - 114900 ' '130000 ' '125000 ' '180000 ' '80000 ' '90000 '
#  '120000 ' '90000 - 120000 ' '76035 - 115830 ' '85000 ' '135000 ' '47484 '
#  '120000 - 130000 ' '75000 - 110000 ' '115000 - 135000 ' '100000 '
#  '90000 - 150000 ' '175000 - 250000 ' '52000 ' '87834 - 117112 '
#  '130000 - 150000 ' '130000 - 170000 ' '130000 - 160000 ' '170000 '
#  '110000 ' '90000 - 170000 ' '70000 - 110000 ' '65000 - 110000 '
#  '70286 - 80829 ' '130000 - 165000 ' '110000 - 111000 ' '140000 - 180000 '
#  '150000 - 185000 ' '60000 - 65000 ' '95000 - 130000 ' '100000 - 200000 '
#  '88305 - 146570 ' '100000 - 120000 ' '100000 - 135000 ' '72000 - 84000 '
#  '70286 - 81000 ' '155000 ' '70286 - 88213 ' '100000 - 180000 '
#  '105000 - 125000 ' '180000 - 220000 ' '78630 - 94500 ' '70286 - 83000 '
#  '59000 - 65000 ' '59708 - 72246 ' '150000 - 300000 ' '78630 - 103332 '
#  '80000 - 100000 ' '65000 - 80000 ' '57150 ' '150000 - 230000 '
#  '95000 - 120000 ' '155000 - 160000 ' '57000 ' '50000 - 62000 '
#  '85000 - 110000 ' '175000 ' '63339 - 76007 ' '55132 - 88211 '
#  '95000 - 127000 ' '100000 - 170000 ' '40000 - 60000 ' '76804 - 100726 '
#  '55000 ' '73286 - 86231 ' '100000 - 109000 ' '60000 - 75000 '
#  '79884 - 104772 ' '190000 ' '200000 ' '45000 - 70000 ' '40092 - 65676 '
#  '23868 - 37752 ' '40000 - 56000 ' '40000 - 72000 ' '30000 '
#  '45000 - 50000 ' '32900 - 59100 ' '53900 - 96900 ' '27400 - 49400 '
#  '125132 - 161900 ' '58600 ' '24000 ' '30000 - 32000 ' '125000 - 160000 '
#  '36700 - 55000 ' '120000 - 150000 ' '110000 - 150000 ' '75000 - 90000 '
#  '40000 - 47000 ' '79000 ' '160000 - 180000 ' '120000 - 165000 '
#  '75000 - 85000 ' '110000 - 140000 ' '70000 - 100000 ' '70000 - 90000 '
#  '110000 - 135000 ' '75000 ' '75000 - 95000 ' '225000 ' '70286 - 87295 '
#  '57969 - 62000 ' '120000 - 200000 ' '140000 - 200000 ' '59708 - 65678 '
#  '68239 - 80000 ' '110000 - 250000 ' '102000 ' '100000 - 110000 '
#  '175000 - 215000 ' '90000 - 160000 ' '97000 ' '70000 - 85000 '
#  '53000 - 98000 ' '35000 ' '82326 - 104374 ' '155000 - 165000 '
#  '80000 - 90000 ' '45000 ']
# Avg_Salary
# 115
# Company
# 146
# Location
# 85
# Salary
# 295
# Title
# 235
# City
# 56
# State
# 17

# %% [markdown]
# ### Since this is a binary classification problem, I want to compute the median salary to create a new variable that is True (1) when the salary is above the median and is False (0) when the salary is below the median.

# %%
#Looks like our median salary is 100K
median_salary = indeed['Avg_Salary'].median()
median_salary
# Out:
# 100000.0

# %%
#Defining a function that will return a 1 if a salary is above 100K and will return a 0 if the salary is below
def above_median(amount):
    if amount > indeed['Avg_Salary'].median():
        return 1
    else:
        return 0

# %%
#Creating a 'Salary_Above_Median' column that will house our 1's and 0's and define which salaries are above and below
#the median
indeed['Salary_Above_Median'] = indeed['Avg_Salary'].apply(lambda x: above_median(x))
indeed['Salary_Above_Median'].value_counts()

#It looks like our results are relatively close with but majority of job listings have a salary below the median.
# Out:
# 0    257
# 1    236
# Name: Salary_Above_Median, dtype: int64

# %%
from matplotlib import pyplot

fig, ax = pyplot.subplots()
fig.set_size_inches(10, 8)
sns.set_context(rc={"font.size":15,"axes.titlesize":15,"axes.labelsize":15})

sns.countplot(ax=ax, data = indeed, x = 'Salary_Above_Median', palette='RdBu_r', saturation=1.0)

sns.plt.show()
fig.savefig('Sat_Jobs_Below_and_Above_Median_Salary.png')

# %% [markdown]
# ### Computing the baseline accuracy for the model

# %%
#The baseline accuracy for this would be close to 50/50 at .48
all_salary = float(indeed['Salary_Above_Median'].count())
all_above_median = float(indeed['Salary_Above_Median'][indeed['Salary_Above_Median'] == 1].count())
base = all_above_median/all_salary

print base
# Out:
# 0.478701825558

# %% [markdown]
# ### Creating a Random Forest model to predict High/Low salary using the location data as the features.

# %%
#Since our dataframe has location split by City and State, I would like to take a look at whether one is a better 
#predictor of salary than the other.
#Below, I am getting dummies and setting the X variable as 'City' and the y as the 'Salary_Above_Median' column. 
#Then, I am doing a train, test, split on the data with a training size of .77 and testing size of .33.
#I am then calling the Random Forest Classifier and fitting the model on my X_train and y_train data.

X = pd.get_dummies(indeed['City'])
y = indeed['Salary_Above_Median']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.33)

rf_city = RandomForestClassifier(class_weight='balanced')

rf_city.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rf_city.predict(X_test)
print confusion_matrix(y_test,y_pred)  #Printing the confusion matrix for city
# Out:
# [[48 27]
#  [16 72]]

# %%
print accuracy_score(y_pred, y_test) #Getting the accuracy score for our city model. Pretty good predictor.
# Out:
# 0.736196319018

# %%
print classification_report(y_test,y_pred) #Getting the model classification report for city.
# Out:
#              precision    recall  f1-score   support
#
#           0       0.75      0.64      0.69        75
#           1       0.73      0.82      0.77        88
#
# avg / total       0.74      0.74      0.73       163

# %%
#Here I am  doing the same thing as above except on the 'State' column
X = pd.get_dummies(indeed['State'])
y = indeed['Salary_Above_Median']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

rf_state = RandomForestClassifier(class_weight='balanced')

rf_state.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rf_state.predict(X_test)  #Printing the confusion matrix for state
print confusion_matrix(y_test,y_pred)
# Out:
# [[37 46]
#  [15 65]]

# %%
accuracy_score(y_pred, y_test) #It doesn't look like state is a good predictor
# Out:
# 0.62576687116564422

# %%
print classification_report(y_test,y_pred) #Printing the classification report for state
# Out:
#              precision    recall  f1-score   support
#
#           0       0.71      0.45      0.55        83
#           1       0.59      0.81      0.68        80
#
# avg / total       0.65      0.63      0.61       163

# %%
#Now to combine the two locations to see whether they are good predictors of salary
X = pd.get_dummies(indeed[['City','State']])
y = indeed['Salary_Above_Median']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

rf_city_state = RandomForestClassifier(class_weight='balanced')

rf_city_state.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rf_city_state.predict(X_test) #printing the confusion matrix for our city_state model
print confusion_matrix(y_test,y_pred)
# Out:
# [[42 41]
#  [12 68]]

# %%
accuracy_score(y_pred, y_test) #Combing our city and state variables made the model a bit better but still not as 
                               #good as just the city model
# Out:
# 0.67484662576687116

# %%
print classification_report(y_test,y_pred) #Printing the classification report
# Out:
#              precision    recall  f1-score   support
#
#           0       0.78      0.51      0.61        83
#           1       0.62      0.85      0.72        80
#
# avg / total       0.70      0.67      0.67       163

# %% [markdown]
# ### Creating a few new variables in the dataframe by extracting keywords from the job titles for later modeling

# %%
#I'm going to grab some keywords from the title column which I think may be good predictors of salary.
#The key words below are going to get their own columns in the dataframe and be represented by a 1 when they
#appear in an individual job title. When they are not found in a job title they will be represented with a 0.
indeed['visualization'] = map(int, indeed['Title'].str.lower().str.contains('vis'))
indeed['scientist'] = map(int, indeed['Title'].str.lower().str.contains('scientist'))
indeed['engineer'] = map(int, indeed['Title'].str.lower().str.contains('engineer'))
indeed['specialist'] = map(int, indeed['Title'].str.lower().str.contains('specialist'))
indeed['analyst'] = map(int, indeed['Title'].str.lower().str.contains('analyst'))
indeed['manager'] = map(int, indeed['Title'].str.lower().str.contains('manager')|
                             indeed['Title'].str.lower().str.contains('mngr')|
                             indeed['Title'].str.lower().str.contains('mgr'))
indeed['senior'] = map(int, (indeed['Title'].str.lower().str.contains('senior') |
                         indeed['Title'].str.lower().str.contains('snr') |
                         indeed['Title'].str.lower().str.contains('sr')))

title_descriptions = ['visualization','scientist','engineer','specialist','analyst','manager', 'senior']
for description in title_descriptions:
    print(description, indeed[description].sum())
# Out:
# ('visualization', 8)
# ('scientist', 180)
# ('engineer', 40)
# ('specialist', 9)
# ('analyst', 117)
# ('manager', 22)
# ('senior', 95)

# %% [markdown]
# ### Tfidf Vectorizer and  Logistic Regression on the job titles

# %%
#Creating a tfid vectorizer and and transforming the entire title column into a matrix and naming it df
tvec = TfidfVectorizer()
tvec.fit(indeed.Title)

df  = pd.DataFrame(tvec.transform(indeed.Title).todense(),
                   columns=tvec.get_feature_names())

# %%
#Fitting all of df (transformed indeed title) as the X and setting the Salary_Above_Median as the y
#Running a train test split with a train size of .77 and test size of .33
X = df
y = indeed.Salary_Above_Median
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.33)

# %%
#Fitting a logistic regression model
lg_title = LogisticRegression()
lg_title.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = lg_title.predict(X_test) # getting the model score. Looks like the title is a pretty good predictor of salary
accuracy_score(y_pred, y_test)
# Out:
# 0.7975460122699386

# %%
confusion_matrix(y_test,y_pred)  #printing the confusion matrix
# Out:
# array([[65, 18],
#        [15, 65]])

# %%
print classification_report(y_test,y_pred) #printing the classification report
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.78      0.80        83
#           1       0.78      0.81      0.80        80
#
# avg / total       0.80      0.80      0.80       163

# %%
#Doing a gradient boost
X = df
y = indeed.Salary_Above_Median

cv = StratifiedKFold(y, n_folds=3, shuffle=True, random_state=41)

gbc = GradientBoostingClassifier()
s = cross_val_score(gbc, X, y, cv=cv, n_jobs=-1)
print "{} Score:\t{:0.3} ± {:0.3}".format("Gradient Boosting", s.mean().round(3), s.std().round(3))
# Out:
# Gradient Boosting Score:	0.856 ± 0.033

# %%
#Running a train, test, split and fitting the title dataframe to a random forest model
X = df
y = indeed['Salary_Above_Median']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

rf_title = RandomForestClassifier(class_weight='balanced')

rf_title.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rf_title.predict(X_test) #printing the confusion matrix for our title model
print confusion_matrix(y_test,y_pred)
# Out:
# [[82  4]
#  [16 61]]

# %%
accuracy_score(y_pred, y_test) #According to our rfmodel,the job title is a pretty damn good predictor of salary
# Out:
# 0.87730061349693256

# %%
print classification_report(y_test,y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.95      0.89        86
#           1       0.94      0.79      0.86        77
#
# avg / total       0.88      0.88      0.88       163

# %%
#Extracting the feature importance from the random forest title model.
#It looks like a couple of the keywords that I extracted from the dataframe earlier are popping up. However,
#the majority of these are not ones that I thought of being good predictors.

rf_features = pd.DataFrame(rf_title.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
rf_features.head(10)
# Out:
#                importance
# data             0.156494
# analyst          0.063656
# research         0.047665
# scientist        0.040732
# machine          0.031026
# senior           0.023991
# engineer         0.023856
# lead             0.023007
# learning         0.019139
# environmental    0.018679

# %% [markdown]
# ### Running a Logistic Regression on just the job title keywords that were extracted earlier

# %%
#Taking just the key words that were created earlier and setting a train test split.
X = indeed[['visualization','scientist','engineer','specialist','analyst','manager', 'senior']]
y = indeed['Salary_Above_Median']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

print X_train.shape, y_train.shape
print X_test.shape, y_test.shape
# Out:
# (330, 7) (330,)
# (163, 7) (163,)

# %%
#Fitting a logistic regression model on the keyword columns and getting the accuracy score.
#Hmm, it doesn't look like the keywords I chose are the best predictors of salary
lg_keywords= LogisticRegression()
lg_keywords.fit(X_train,y_train)

y_pred = lg_keywords.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.71779141104294475

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[64, 22],
#        [24, 53]])

# %%
print classification_report(y_test,y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.73      0.74      0.74        86
#           1       0.71      0.69      0.70        77
#
# avg / total       0.72      0.72      0.72       163

# %% [markdown]
# ### Using cross-validation to evaluate the job title model

# %%
#I am doing a 6 fold cross validation on my title model (df)
scores = cross_val_score(lg_title, X, y, cv = 6)

# %%
print scores #Below are my 6 model scores
# Out:
# [ 0.86746988  0.89156627  0.91463415  0.84146341  0.87804878  0.67901235]

# %%
predictions = cross_val_predict(lg_keywords, X , y, cv=6)

# %%
accuracy = accuracy_score(y, predictions)    #This is a decent model score that falls between the high score of 0.877
print "Cross-Predicted Accuracy:", accuracy  #that I got from the random forest and the low of 0.797 that I got from 
                                             # the logistic regression model
# Out:
# Cross-Predicted Accuracy: 0.84584178499
